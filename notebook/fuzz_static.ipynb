# %% [markdown]
# ## Import Libraries

# %%
import re
from typing import Tuple

import torch
import h5py
import librosa
from torch import nn
import torch.nn.functional as F
from torch.optim.lr_scheduler import ReduceLROnPlateau

# %% [markdown]
# ## Neural WDF for Two-Port Resistor

# %%
class TwoPort(nn.Module):
    def __init__(self):
        super(TwoPort, self).__init__()
        self.fc1 = nn.Linear(2, 32)
        self.fc2 = nn.Linear(32, 2)

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# %% [markdown]
# ## Neural WDF for Fuzz Circuit

# %%
class FuzzStatic(nn.Module):
    def __init__(self, alpha_lin=0.5, alpha_vol=0.5, fs=48e3, s_path="S.hdf5", z_path="Z.hdf5", dtype=torch.float32):
        super(FuzzStatic, self).__init__()
        self.dtype = dtype

        # Circuit parameters
        self.C71 = torch.tensor(4.7e-6, dtype=self.dtype)
        self.Rin = torch.tensor(22e3, dtype=self.dtype)
        self.R72 = torch.tensor(50e3, dtype=self.dtype)
        self.C81 = torch.tensor(4.7e-6, dtype=self.dtype)
        self.R81 = torch.tensor(22e3, dtype=self.dtype)
        self.Rout = torch.tensor(100e3, dtype=self.dtype)
        self.C91 = torch.tensor(4.7e-6, dtype=self.dtype)
        self.R_vol = torch.tensor(50e3, dtype=self.dtype)
        self.C94 = torch.tensor(4.7e-6, dtype=self.dtype)


        # User parameters
        self.alpha_lin = alpha_lin
        self.alpha_vol = alpha_vol
        self.fs = fs


        # WDF structure parameters
        self.a_C71_ic = torch.nn.Parameter(torch.tensor(0.0, dtype=self.dtype))
        self.a_C81_ic = torch.nn.Parameter(torch.tensor(0.0, dtype=self.dtype))
        self.a_C91_ic = torch.nn.Parameter(torch.tensor(0.0, dtype=self.dtype))
        self.a_C94_ic = torch.nn.Parameter(torch.tensor(0.0, dtype=self.dtype))
        self.a_C71 = torch.tensor(0.0, dtype=self.dtype)
        self.a_C81 = torch.tensor(0.0, dtype=self.dtype)
        self.a_C91 = torch.tensor(0.0, dtype=self.dtype)
        self.a_C94 = torch.tensor(0.0, dtype=self.dtype)
        self.b_C71 = torch.tensor(0.0, dtype=self.dtype)
        self.b_C81 = torch.tensor(0.0, dtype=self.dtype)
        self.b_C91 = torch.tensor(0.0, dtype=self.dtype)
        self.b_C94 = torch.tensor(0.0, dtype=self.dtype)

        self.b_S71_0 = torch.tensor(0.0, dtype=self.dtype)
        self.b_P72_0 = torch.tensor(0.0, dtype=self.dtype)
        self.b_P81_0 = torch.tensor(0.0, dtype=self.dtype)
        self.b_S91_0 = torch.tensor(0.0, dtype=self.dtype)
        self.b_P92_0 = torch.tensor(0.0, dtype=self.dtype)
        self.b_S93_0 = torch.tensor(0.0, dtype=self.dtype)
        self.b_S94_0 = torch.tensor(0.0, dtype=self.dtype)
        self.b_S71_1 = torch.tensor(0.0, dtype=self.dtype)
        self.b_P81_1 = torch.tensor(0.0, dtype=self.dtype)
        self.b_S91_1 = torch.tensor(0.0, dtype=self.dtype)
        self.b_S94_1 = torch.tensor(0.0, dtype=self.dtype)
        self.b_P72_2 = torch.tensor(0.0, dtype=self.dtype)
        self.b_P81_2 = torch.tensor(0.0, dtype=self.dtype)
        self.b_S91_2 = torch.tensor(0.0, dtype=self.dtype)
        self.b_P92_2 = torch.tensor(0.0, dtype=self.dtype)
        self.b_S93_2 = torch.tensor(0.0, dtype=self.dtype)
        self.b_S94_2 = torch.tensor(0.0, dtype=self.dtype)

        self.a0 = torch.tensor(0.0, dtype=self.dtype)
        self.a1 = torch.tensor(0.0, dtype=self.dtype)
        self.a2 = torch.tensor(0.0, dtype=self.dtype)
        self.a3 = torch.tensor(0.0, dtype=self.dtype)
        self.a4 = torch.tensor(0.0, dtype=self.dtype)
        self.a5 = torch.tensor(9.0, dtype=self.dtype)
        self.b0 = torch.tensor(0.0, dtype=self.dtype)
        self.b1 = torch.tensor(0.0, dtype=self.dtype)
        self.b2 = torch.tensor(0.0, dtype=self.dtype)
        self.b3 = torch.tensor(0.0, dtype=self.dtype)
        self.b4 = torch.tensor(0.0, dtype=self.dtype)


        # WDF scattering matrices of series and parallel junctions
        self.S_S71, self.S_P72 = self.get_scattering_matrix_port7()
        self.S_P81 = self.get_scattering_matrix_port8()
        self.S_S91, self.S_P92, self.S_S93, self.S_S94 = self.get_scattering_matrix_port9()


        # WDF scattering matrix of the R-type junction
        self.fs_dict = {
            44.1e3 : 0,
            48e3   : 1,
            88.2e3 : 2,
            96e3   : 3,
            176.4e3: 4,
            192e3  : 5
        }
        # STEP 1: Load the scattering and free-parameter impedance matrices from the HDF5 file
        with h5py.File(s_path, "r") as file:
            self.S_matlab = torch.as_tensor(file["/S"][:].T).to(dtype=self.dtype)
        with h5py.File(z_path, "r") as file:
            self.Z_matlab = torch.as_tensor(file["/Z"][:].T).to(dtype=self.dtype)
        # STEP 2: Get the scattering and free-parameter impedance matrices for the given fs, alpha_lin, and alpha_vol
        self.S, self.S_forward, self.S_backward, self.Z, self.Z_root = self.get_scattering_matrix_rtype()
        

        # Initialize two-port resistor
        self.R1 = torch.tensor(23e3, dtype=self.dtype)
        self.R2 = torch.tensor(12e3, dtype=self.dtype)
        self.R = torch.diag(torch.tensor([self.R1, self.R2]))
        
        self.Z_root_inv = torch.inverse(self.Z_root)
        self.Sr_gt = torch.inverse(self.R @ self.Z_root_inv + torch.eye(2)) @ (self.R @ self.Z_root_inv - torch.eye(2))
        self.Sr = torch.nn.Linear(2, 2, bias=False, dtype=self.dtype)
        self.nn = TwoPort()
        self.nn.load_state_dict(torch.load("checkpoint.pth"))


    def get_scattering_matrix_port7(self):
        Z_R71 = self.Rin
        Z_C71 = 1 / (2 * self.fs * self.C71)
        Z_S71 = torch.stack((
            Z_R71 + Z_C71,
            Z_C71,
            Z_R71
        ))

        Z_R72 = self.R72
        Z_P72 = torch.stack((
            (Z_S71[0] * Z_R72) / (Z_S71[0] + Z_R72),
            Z_R72,
            Z_S71[0]
        ))
        return (
            self.get_scattering_matrix_series(Z_S71),
            self.get_scattering_matrix_parallel(Z_P72)
        )


    def get_scattering_matrix_port8(self):
        Z_R81 = self.R81
        Z_C81 = 1 / (2 * self.fs * self.C81)
        Z_P81 = torch.stack((
            (Z_R81 * Z_C81) / (Z_R81 + Z_C81),
            Z_C81,
            Z_R81
        ))
        return self.get_scattering_matrix_parallel(Z_P81)


    def get_scattering_matrix_port9(self):
        Z_R91 = self.Rout
        Z_C91 = 1 / (2 * self.fs * self.C91)
        Z_S91 = torch.stack((
            Z_R91 + Z_C91,
            Z_R91,
            Z_C91
        ))

        R92 = self.alpha_vol * self.R_vol 
        Z_R92 = R92
        Z_P92 = torch.stack((
            (Z_R92 * Z_S91[0]) / (Z_R92 + Z_S91[0]),
            Z_R92,
            Z_S91[0]
        ))        

        R93 = (1 - self.alpha_vol) * self.R_vol
        Z_R93 = R93
        Z_S93 = torch.stack((
            Z_R93 + Z_P92[0],
            Z_R93,
            Z_P92[0]
        ))
        
        Z_C94 = 1 / (2 * self.fs * self.C94)
        Z_S94 = torch.stack((
            Z_C94 + Z_S93[0],
            Z_C94,
            Z_S93[0]
        ))
        
        return (
            self.get_scattering_matrix_series(Z_S91),
            self.get_scattering_matrix_parallel(Z_P92),
            self.get_scattering_matrix_series(Z_S93),
            self.get_scattering_matrix_series(Z_S94)
        )


    def get_scattering_matrix_series(self, Z):
        # STEP 0: Formate the free-parameter impedance matrix Z and get the number of ports
        Z = torch.diag(Z)
        num_ports = Z.shape[0]
        
        # STEP 1: Formulate fundamental loop matrix of the series junction
        B = torch.ones(1, num_ports, dtype=self.dtype)
        
        # STEP 2: Calculate the scattering matrix using the general WD junction method
        I = torch.eye(num_ports, dtype=self.dtype)
        S = I - 2 * Z @ B.T @ torch.inverse(B @ Z @ B.T) @ B
        
        # STEP 3: Return the scattering matrix
        return S


    def get_scattering_matrix_parallel(self, Z):
        # STEP 0: Formate the free-parameter impedance matrix Z and get the number of ports
        Z = torch.diag(Z)
        num_ports = Z.shape[0]
        
        # STEP 1: Formulate fundamental cut-set matrix
        Q = torch.ones(1, num_ports, dtype=self.dtype)
        
        # STEP 2: Calculate the scattering matrix using the general WD junction method
        I = torch.eye(num_ports, dtype=self.dtype)
        Z_inv = torch.inverse(Z)
        S = 2 * Q.T @ torch.inverse(Q @ Z_inv @ Q.T) @ Q @ Z_inv - I
        
        # STEP 3: Return the scattering matrix
        return S


    def get_scattering_matrix_rtype(self):
        fs_index = self.fs_dict[self.fs]
        alpha_lin_index = round(self.alpha_lin * 100)
        alpha_vol_index = round(self.alpha_vol * 100)

        S = self.S_matlab[fs_index, alpha_lin_index, alpha_vol_index, :, :]
        S_forward = S[0:2, 6:10]
        S_backward = torch.cat((S[6:9, 0:2], S[6:9, 6:10]), dim=1)

        Z = self.Z_matlab[fs_index, alpha_lin_index, alpha_vol_index, :, :]
        Z_root = Z[0:2, 0:2]

        return (
            S,
            S_forward,
            S_backward,
            Z,
            Z_root
        )


    def reset_waves(self):
        self.a_C71 = self.a_C71_ic * 1.0
        self.a_C81 = self.a_C81_ic * 1.0
        self.a_C91 = self.a_C91_ic * 1.0
        self.a_C94 = self.a_C94_ic * 1.0
        self.b_C71 = torch.tensor(0.0, dtype=self.dtype)
        self.b_C81 = torch.tensor(0.0, dtype=self.dtype)
        self.b_C91 = torch.tensor(0.0, dtype=self.dtype)
        self.b_C94 = torch.tensor(0.0, dtype=self.dtype)

        self.b_S71_0 = torch.tensor(0.0, dtype=self.dtype)
        self.b_P72_0 = torch.tensor(0.0, dtype=self.dtype)
        self.b_P81_0 = torch.tensor(0.0, dtype=self.dtype)
        self.b_S91_0 = torch.tensor(0.0, dtype=self.dtype)
        self.b_P92_0 = torch.tensor(0.0, dtype=self.dtype)
        self.b_S93_0 = torch.tensor(0.0, dtype=self.dtype)
        self.b_S94_0 = torch.tensor(0.0, dtype=self.dtype)
        self.b_S71_1 = torch.tensor(0.0, dtype=self.dtype)
        self.b_P81_1 = torch.tensor(0.0, dtype=self.dtype)
        self.b_S91_1 = torch.tensor(0.0, dtype=self.dtype)
        self.b_S94_1 = torch.tensor(0.0, dtype=self.dtype)
        self.b_P72_2 = torch.tensor(0.0, dtype=self.dtype)
        self.b_P81_2 = torch.tensor(0.0, dtype=self.dtype)
        self.b_S91_2 = torch.tensor(0.0, dtype=self.dtype)
        self.b_P92_2 = torch.tensor(0.0, dtype=self.dtype)
        self.b_S93_2 = torch.tensor(0.0, dtype=self.dtype)
        self.b_S94_2 = torch.tensor(0.0, dtype=self.dtype)

        self.a0 = torch.tensor(0.0, dtype=self.dtype)
        self.a1 = torch.tensor(0.0, dtype=self.dtype)
        self.a2 = torch.tensor(0.0, dtype=self.dtype)
        self.a3 = torch.tensor(0.0, dtype=self.dtype)
        self.a4 = torch.tensor(0.0, dtype=self.dtype)
        self.a5 = torch.tensor(9.0, dtype=self.dtype)
        self.b0 = torch.tensor(0.0, dtype=self.dtype)
        self.b1 = torch.tensor(0.0, dtype=self.dtype)
        self.b2 = torch.tensor(0.0, dtype=self.dtype)
        self.b3 = torch.tensor(0.0, dtype=self.dtype)
        self.b4 = torch.tensor(0.0, dtype=self.dtype)


    def solve_dc(self, dc_in=0.0, epsilon=1e-10):
        # STEP 0: Reset the waves to DC=0 state
        self.a_C71 = torch.tensor(-3.7427606943372482, dtype=self.dtype)
        self.a_C81 = torch.tensor(1.8297941172302856, dtype=self.dtype)
        self.a_C91 = torch.tensor(-4.440665733659135e-12, dtype=self.dtype)
        self.a_C94 = torch.tensor(-5.598253191650242, dtype=self.dtype)
        # Check if the input is DC=0
        if dc_in == 0.0:
            return self.a_C71, self.a_C81, self.a_C91, self.a_C94

        # STEP 1: Prepare the WDF structure for the DC analysis
        is_stable = False
        error_eps = epsilon

        # STEP 2: Iterate the WDF structure until the states of capacitors and inductors are stable
        ii = 0
        while not is_stable:
            ii += 1

            # Manage capacitors and inductors' states
            self.b_C71 = self.a_C71
            self.b_C81 = self.a_C81
            self.b_C91 = self.a_C91
            self.b_C94 = self.a_C94

            # Forward scanning
            self.b_S71_0 = self.S_S71[0, 1] * self.b_C71 + self.S_S71[0, 2] * dc_in
            self.b_P72_0 = self.S_P72[0, 2] * self.b_S71_0
            self.b_P81_0 = self.S_P81[0, 1] * self.b_C81
            self.b_S91_0 = self.S_S91[0, 2] * self.b_C91
            self.b_P92_0 = self.S_P92[0, 2] * self.b_S91_0
            self.b_S93_0 = self.S_S93[0, 2] * self.b_P92_0
            self.b_S94_0 = self.S_S94[0, 1] * self.b_C94 + self.S_S94[0, 2] * self.b_S93_0
            
            self.a2 = self.b_P72_0
            self.a3 = self.b_P81_0
            self.a4 = self.b_S94_0

            # Local scattering
            self.b0, self.b1 = self.S_forward @ torch.stack([self.a2, self.a3, self.a4, self.a5])
            self.a0, self.a1 = self.nn(torch.stack([self.b0, self.b1]))
            self.b2, self.b3, self.b4 = self.S_backward @ torch.stack([self.a0, self.a1, self.a2, self.a3, self.a4, self.a5])

            # Backward scanning
            self.b_P72_2 = self.S_P72[2, 0] * self.b2 + self.S_P72[2, 2] * self.b_S71_0
            self.b_S71_1 = self.S_S71[1, 0] * self.b_P72_2 + self.S_S71[1, 1] * self.b_C71 + self.S_S71[1, 2] * dc_in
            self.b_P81_1 = self.S_P81[1, 0] * self.b3 + self.S_P81[1, 1] * self.b_C81
            self.b_S94_1, self.b_S94_2 = self.S_S94[1:3, :] @ torch.stack([self.b4, self.b_C94, self.b_S93_0])
            self.b_S93_2 = self.S_S93[2, 0] * self.b_S94_2 + self.S_S93[2, 2] * self.b_P92_0
            self.b_P92_2 = self.S_P92[2, 0] * self.b_S93_2 + self.S_P92[2, 2] * self.b_S91_0
            self.b_S91_2 = self.S_S91[2, 0] * self.b_P92_2 + self.S_S91[2, 2] * self.b_C91

            # Check if the states of capacitors and inductors are stable
            if (
                torch.abs(self.b_C71 - self.b_S71_1) > error_eps
                or torch.abs(self.b_C81 - self.b_P81_1) > error_eps
                or torch.abs(self.b_C91 - self.b_S91_2) > error_eps
                or torch.abs(self.b_C94 - self.b_S94_1) > error_eps
            ):
                self.a_C71 = self.b_S71_1
                self.a_C81 = self.b_P81_1
                self.a_C91 = self.b_S91_2
                self.a_C94 = self.b_S94_1
            else:
                is_stable = True

        print("Iterations:", ii)
        print(
            "Stable states:\n  C71:",
            self.a_C71,
            "\n  C81:",
            self.a_C81,
            "\n  C91:",
            self.a_C91,
            "\n  C94:",
            self.a_C94,
        )

        return self.a_C71, self.a_C81, self.a_C91, self.a_C94


    def set_capacitors_initial_states(self, C71, C81, C91, C94):
        self.a_C71 = C71
        self.a_C81 = C81
        self.a_C91 = C91
        self.a_C94 = C94


    def forward(self, vin):
        vout = torch.zeros_like(vin)

        for i in range(vin.shape[0]):
            # Manage capacitors and inductors' states
            self.b_C71 = self.a_C71
            self.b_C81 = self.a_C81
            self.b_C91 = self.a_C91
            self.b_C94 = self.a_C94

            # Forward scanning
            self.b_S71_0 = self.S_S71[0, 1] * self.b_C71 + self.S_S71[0, 2] * vin[i, 0]
            self.b_P72_0 = self.S_P72[0, 2] * self.b_S71_0
            self.b_P81_0 = self.S_P81[0, 1] * self.b_C81
            self.b_S91_0 = self.S_S91[0, 2] * self.b_C91
            self.b_P92_0 = self.S_P92[0, 2] * self.b_S91_0
            self.b_S93_0 = self.S_S93[0, 2] * self.b_P92_0
            self.b_S94_0 = self.S_S94[0, 1] * self.b_C94 + self.S_S94[0, 2] * self.b_S93_0
            
            self.a2 = self.b_P72_0
            self.a3 = self.b_P81_0
            self.a4 = self.b_S94_0

            # Local scattering
            self.b0, self.b1 = self.S_forward @ torch.stack([self.a2, self.a3, self.a4, self.a5])
            self.a0, self.a1 = self.nn(torch.stack([self.b0, self.b1]))
            self.b2, self.b3, self.b4 = self.S_backward @ torch.stack([self.a0, self.a1, self.a2, self.a3, self.a4, self.a5])
            
            # Backward scanning
            self.b_P72_2 = self.S_P72[2, 0] * self.b2 + self.S_P72[2, 2] * self.b_S71_0
            self.b_S71_1 = self.S_S71[1, 0] * self.b_P72_2 + self.S_S71[1, 1] * self.b_C71 + self.S_S71[1, 2] * vin[i, 0]
            self.b_P81_1 = self.S_P81[1, 0] * self.b3 + self.S_P81[1, 1] * self.b_C81
            self.b_S94_1, self.b_S94_2 = self.S_S94[1:3, :] @ torch.stack([self.b4, self.b_C94, self.b_S93_0])
            self.b_S93_2 = self.S_S93[2, 0] * self.b_S94_2 + self.S_S93[2, 2] * self.b_P92_0
            self.b_P92_2 = self.S_P92[2, 0] * self.b_S93_2 + self.S_P92[2, 2] * self.b_S91_0
            self.b_S91_1 = self.S_S91[1, 0] * self.b_P92_2 + self.S_S91[1, 2] * self.b_C91
            self.b_S91_2 = self.S_S91[2, 0] * self.b_P92_2 + self.S_S91[2, 2] * self.b_C91
            
            self.a_C71 = self.b_S71_1
            self.a_C81 = self.b_P81_1
            self.a_C91 = self.b_S91_2
            self.a_C94 = self.b_S94_1
            
            vout[i, 0] = self.b_S91_1 / 2
        
        return vout


# vin, fs = librosa.load("./matlab/input_fuzz_static.wav", sr=None)
# vin = torch.tensor(vin, dtype=torch.float32).unsqueeze(1)

# model = FuzzStatic()
# model.init_waves()
# v_wdf = model(vin)

# %% [markdown]
# ## Loss Function

# %%
class ESRLoss(nn.Module):
    def __init__(self):
        super(ESRLoss, self).__init__()

    def forward(self, y_true, y_pred):
        return torch.sum((y_true - y_pred)**2) / torch.sum(y_true**2)
    
class DCLoss(nn.Module):
    def __init__(self):
        super(DCLoss, self).__init__()

    def forward(self, y_true, y_pred):
        numerator = torch.abs(torch.mean(y_true - y_pred))**2
        denominator = torch.mean(y_true ** 2)
        return numerator / denominator

class CombinedSignalLoss(nn.Module):
    def __init__(self):
        super().__init__()

    def forward(self, y_target, y_pred):
        diff = y_target - y_pred
        diff2 = diff ** 2
        y_energy = y_target ** 2
        
        loss_mse = torch.mean(diff2)
        loss_esr = torch.sum(diff2) / torch.sum(y_energy)
        loss_dc = torch.abs(torch.mean(diff))**2 / torch.mean(y_energy)
        return loss_mse + loss_esr + loss_dc

# %% [markdown]
# ## Training Loop

# %%
vin, fs = librosa.load("./ltspice/input_fuzz_static.wav", sr=None)
vin = torch.tensor(vin, dtype=torch.float32).unsqueeze(1)
v_spice = librosa.load("./ltspice/output_fuzz_static.wav", sr=None)[0]
v_spice = torch.tensor(v_spice, dtype=torch.float32).unsqueeze(1) * 4

model = FuzzStatic()
loss_func_train = nn.MSELoss()
loss_func_valid = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-2)
# scheduler = ReduceLROnPlateau(optimizer, factor=0.5, patience=5)

for epoch in range(1000):
    model.reset_waves()
    v_wdf = model(vin)
    loss = loss_func_train(v_wdf, v_spice)
    
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    # scheduler.step(loss)
    
    print(f"Epoch {epoch+1}: Combined = {loss.item():.6e} \t MSE = {loss_func_valid(v_wdf, v_spice).item():.6e}")
# Out:
# Epoch 1: Combined = 5.318244e-01 	 MSE = 5.318244e-01
# Epoch 2: Combined = 4.816558e-01 	 MSE = 4.816558e-01
# Epoch 3: Combined = 4.428030e-01 	 MSE = 4.428030e-01
# Epoch 4: Combined = 4.133740e-01 	 MSE = 4.133740e-01
# Epoch 5: Combined = 3.921748e-01 	 MSE = 3.921748e-01
# Epoch 6: Combined = 3.859699e-01 	 MSE = 3.859699e-01
# Epoch 7: Combined = 3.958892e-01 	 MSE = 3.958892e-01
# Epoch 8: Combined = 4.044045e-01 	 MSE = 4.044045e-01
# Epoch 9: Combined = 4.027865e-01 	 MSE = 4.027865e-01
# Epoch 10: Combined = 3.942882e-01 	 MSE = 3.942882e-01
# Epoch 11: Combined = 3.854336e-01 	 MSE = 3.854336e-01
# Epoch 12: Combined = 3.794582e-01 	 MSE = 3.794582e-01
# Epoch 13: Combined = 3.764251e-01 	 MSE = 3.764251e-01
# Epoch 14: Combined = 3.750862e-01 	 MSE = 3.750862e-01
# Epoch 15: Combined = 3.748213e-01 	 MSE = 3.748213e-01
# Epoch 16: Combined = 3.746952e-01 	 MSE = 3.746952e-01
# Epoch 17: Combined = 3.742082e-01 	 MSE = 3.742082e-01
# Epoch 18: Combined = 3.730970e-01 	 MSE = 3.730970e-01
# Epoch 19: Combined = 3.713137e-01 	 MSE = 3.713137e-01
# Epoch 20: Combined = 3.689423e-01 	 MSE = 3.689423e-01
# Epoch 21: Combined = 3.661315e-01 	 MSE = 3.661315e-01
# Epoch 22: Combined = 3.630809e-01 	 MSE = 3.630809e-01
# Epoch 23: Combined = 3.600971e-01 	 MSE = 3.600971e-01
# Epoch 24: Combined = 3.573818e-01 	 MSE = 3.573818e-01
# Epoch 25: Combined = 3.548334e-01 	 MSE = 3.548334e-01
# Epoch 26: Combined = 3.524447e-01 	 MSE = 3.524447e-01
# Epoch 27: Combined = 3.502585e-01 	 MSE = 3.502585e-01
# Epoch 28: Combined = 3.480504e-01 	 MSE = 3.480504e-01
# Epoch 29: Combined = 3.455234e-01 	 MSE = 3.455234e-01
# Epoch 30: Combined = 3.425214e-01 	 MSE = 3.425214e-01
# Epoch 31: Combined = 3.390371e-01 	 MSE = 3.390371e-01
# Epoch 32: Combined = 3.351012e-01 	 MSE = 3.351012e-01
# Epoch 33: Combined = 3.307322e-01 	 MSE = 3.307322e-01
# Epoch 34: Combined = 3.259704e-01 	 MSE = 3.259704e-01
# Epoch 35: Combined = 3.213363e-01 	 MSE = 3.213363e-01
# Epoch 36: Combined = 3.168972e-01 	 MSE = 3.168972e-01
# Epoch 37: Combined = 3.125135e-01 	 MSE = 3.125135e-01
# Epoch 38: Combined = 3.077638e-01 	 MSE = 3.077638e-01
# Epoch 39: Combined = 3.022452e-01 	 MSE = 3.022452e-01
# Epoch 40: Combined = 2.961223e-01 	 MSE = 2.961223e-01
# Epoch 41: Combined = 2.898744e-01 	 MSE = 2.898744e-01
# Epoch 42: Combined = 2.834603e-01 	 MSE = 2.834603e-01
# Epoch 43: Combined = 2.770461e-01 	 MSE = 2.770461e-01
# Epoch 44: Combined = 2.703274e-01 	 MSE = 2.703274e-01
# Epoch 45: Combined = 2.633628e-01 	 MSE = 2.633628e-01
# Epoch 46: Combined = 2.555743e-01 	 MSE = 2.555743e-01
# Epoch 47: Combined = 2.476596e-01 	 MSE = 2.476596e-01
# Epoch 48: Combined = 2.398560e-01 	 MSE = 2.398560e-01
# Epoch 49: Combined = 2.322748e-01 	 MSE = 2.322748e-01
# Epoch 50: Combined = 2.244931e-01 	 MSE = 2.244931e-01
# Epoch 51: Combined = 2.165750e-01 	 MSE = 2.165750e-01
# Epoch 52: Combined = 2.089042e-01 	 MSE = 2.089042e-01
# Epoch 53: Combined = 2.017554e-01 	 MSE = 2.017554e-01
# Epoch 54: Combined = 1.949883e-01 	 MSE = 1.949883e-01
# Epoch 55: Combined = 1.887349e-01 	 MSE = 1.887349e-01
# Epoch 56: Combined = 1.832305e-01 	 MSE = 1.832305e-01
# Epoch 57: Combined = 1.783317e-01 	 MSE = 1.783317e-01
# Epoch 58: Combined = 1.739478e-01 	 MSE = 1.739478e-01
# Epoch 59: Combined = 1.703067e-01 	 MSE = 1.703067e-01
# Epoch 60: Combined = 1.670087e-01 	 MSE = 1.670087e-01
# Epoch 61: Combined = 1.641044e-01 	 MSE = 1.641044e-01
# Epoch 62: Combined = 1.610270e-01 	 MSE = 1.610270e-01
# Epoch 63: Combined = 1.584998e-01 	 MSE = 1.584998e-01
# Epoch 64: Combined = 1.552791e-01 	 MSE = 1.552791e-01
# Epoch 65: Combined = 1.517737e-01 	 MSE = 1.517737e-01
# Epoch 66: Combined = 1.480484e-01 	 MSE = 1.480484e-01
# Epoch 67: Combined = 1.439424e-01 	 MSE = 1.439424e-01
# Epoch 68: Combined = 1.394242e-01 	 MSE = 1.394242e-01
# Epoch 69: Combined = 1.349589e-01 	 MSE = 1.349589e-01
# Epoch 70: Combined = 1.308642e-01 	 MSE = 1.308642e-01
# Epoch 71: Combined = 1.281945e-01 	 MSE = 1.281945e-01
# Epoch 72: Combined = 1.342822e-01 	 MSE = 1.342822e-01
# Epoch 73: Combined = 1.279647e-01 	 MSE = 1.279647e-01
# Epoch 74: Combined = 1.201775e-01 	 MSE = 1.201775e-01
# Epoch 75: Combined = 1.195403e-01 	 MSE = 1.195403e-01
# Epoch 76: Combined = 1.189389e-01 	 MSE = 1.189389e-01
# Epoch 77: Combined = 1.135436e-01 	 MSE = 1.135436e-01
# Epoch 78: Combined = 1.109018e-01 	 MSE = 1.109018e-01
# Epoch 79: Combined = 1.113574e-01 	 MSE = 1.113574e-01
# Epoch 80: Combined = 1.068641e-01 	 MSE = 1.068641e-01
# Epoch 81: Combined = 1.036089e-01 	 MSE = 1.036089e-01
# Epoch 82: Combined = 1.046180e-01 	 MSE = 1.046180e-01
# Epoch 83: Combined = 1.004919e-01 	 MSE = 1.004919e-01
# Epoch 84: Combined = 9.764909e-02 	 MSE = 9.764909e-02
# Epoch 85: Combined = 9.811039e-02 	 MSE = 9.811039e-02
# Epoch 86: Combined = 9.462030e-02 	 MSE = 9.462030e-02
# Epoch 87: Combined = 9.226583e-02 	 MSE = 9.226583e-02
# Epoch 88: Combined = 9.268770e-02 	 MSE = 9.268770e-02
# Epoch 525: Combined = 1.841108e-02 	 MSE = 1.841108e-02
# Epoch 526: Combined = 2.190242e-02 	 MSE = 2.190242e-02
# Epoch 527: Combined = 2.106556e-02 	 MSE = 2.106556e-02
# Epoch 528: Combined = 1.702618e-02 	 MSE = 1.702618e-02
# Epoch 529: Combined = 1.704197e-02 	 MSE = 1.704197e-02
# Epoch 530: Combined = 1.987409e-02 	 MSE = 1.987409e-02
# Epoch 531: Combined = 1.988269e-02 	 MSE = 1.988269e-02
# Epoch 532: Combined = 1.738588e-02 	 MSE = 1.738588e-02
# Epoch 533: Combined = 1.581576e-02 	 MSE = 1.581576e-02
# Epoch 534: Combined = 1.676082e-02 	 MSE = 1.676082e-02
# Epoch 535: Combined = 1.834607e-02 	 MSE = 1.834607e-02
# Epoch 536: Combined = 1.833546e-02 	 MSE = 1.833546e-02
# Epoch 537: Combined = 1.706588e-02 	 MSE = 1.706588e-02
# Epoch 538: Combined = 1.564363e-02 	 MSE = 1.564363e-02
# Epoch 539: Combined = 1.523944e-02 	 MSE = 1.523944e-02
# Epoch 540: Combined = 1.584569e-02 	 MSE = 1.584569e-02
# Epoch 541: Combined = 1.669620e-02 	 MSE = 1.669620e-02
# Epoch 542: Combined = 1.728980e-02 	 MSE = 1.728980e-02
# Epoch 543: Combined = 1.708430e-02 	 MSE = 1.708430e-02
# Epoch 544: Combined = 1.647739e-02 	 MSE = 1.647739e-02
# Epoch 545: Combined = 1.558780e-02 	 MSE = 1.558780e-02
# Epoch 546: Combined = 1.481650e-02 	 MSE = 1.481650e-02
# Epoch 547: Combined = 1.436883e-02 	 MSE = 1.436883e-02
# Epoch 548: Combined = 1.431914e-02 	 MSE = 1.431914e-02
# Epoch 549: Combined = 1.454010e-02 	 MSE = 1.454010e-02
# Epoch 550: Combined = 1.488105e-02 	 MSE = 1.488105e-02
# Epoch 551: Combined = 1.527167e-02 	 MSE = 1.527167e-02
# Epoch 552: Combined = 1.568699e-02 	 MSE = 1.568699e-02
# Epoch 553: Combined = 1.635638e-02 	 MSE = 1.635638e-02
# Epoch 554: Combined = 1.726839e-02 	 MSE = 1.726839e-02
# Epoch 555: Combined = 1.918080e-02 	 MSE = 1.918080e-02
# Epoch 556: Combined = 2.097491e-02 	 MSE = 2.097491e-02
# Epoch 557: Combined = 2.472403e-02 	 MSE = 2.472403e-02
# Epoch 558: Combined = 2.369479e-02 	 MSE = 2.369479e-02
# Epoch 559: Combined = 2.282267e-02 	 MSE = 2.282267e-02
# Epoch 560: Combined = 1.708038e-02 	 MSE = 1.708038e-02
# Epoch 561: Combined = 1.351829e-02 	 MSE = 1.351829e-02
# Epoch 562: Combined = 1.389082e-02 	 MSE = 1.389082e-02
# Epoch 563: Combined = 1.656654e-02 	 MSE = 1.656654e-02
# Epoch 564: Combined = 1.842154e-02 	 MSE = 1.842154e-02
# Epoch 565: Combined = 1.645630e-02 	 MSE = 1.645630e-02
# Epoch 566: Combined = 1.384197e-02 	 MSE = 1.384197e-02
# Epoch 567: Combined = 1.241534e-02 	 MSE = 1.241534e-02
# Epoch 568: Combined = 1.291352e-02 	 MSE = 1.291352e-02
# Epoch 569: Combined = 1.524277e-02 	 MSE = 1.524277e-02
# Epoch 570: Combined = 2.122770e-02 	 MSE = 2.122770e-02
# Epoch 571: Combined = 3.354797e-02 	 MSE = 3.354797e-02
# Epoch 572: Combined = 3.130868e-02 	 MSE = 3.130868e-02
# Epoch 573: Combined = 3.174238e-02 	 MSE = 3.174238e-02
# Epoch 574: Combined = 1.585218e-02 	 MSE = 1.585218e-02
# Epoch 575: Combined = 1.266710e-02 	 MSE = 1.266710e-02
# Epoch 576: Combined = 2.065258e-02 	 MSE = 2.065258e-02
# Epoch 577: Combined = 2.117612e-02 	 MSE = 2.117612e-02
# Epoch 578: Combined = 1.570444e-02 	 MSE = 1.570444e-02
# Epoch 579: Combined = 1.192146e-02 	 MSE = 1.192146e-02
# Epoch 580: Combined = 1.590872e-02 	 MSE = 1.590872e-02
# Epoch 581: Combined = 1.888941e-02 	 MSE = 1.888941e-02
# Epoch 582: Combined = 1.367680e-02 	 MSE = 1.367680e-02
# Epoch 583: Combined = 1.171629e-02 	 MSE = 1.171629e-02
# Epoch 584: Combined = 1.493423e-02 	 MSE = 1.493423e-02
# Epoch 585: Combined = 1.571908e-02 	 MSE = 1.571908e-02
# Epoch 586: Combined = 1.335140e-02 	 MSE = 1.335140e-02
# Epoch 587: Combined = 1.101810e-02 	 MSE = 1.101810e-02
# Epoch 588: Combined = 1.209731e-02 	 MSE = 1.209731e-02
# Epoch 589: Combined = 1.422496e-02 	 MSE = 1.422496e-02
# Epoch 590: Combined = 1.371491e-02 	 MSE = 1.371491e-02
# Epoch 591: Combined = 1.215932e-02 	 MSE = 1.215932e-02
# Epoch 592: Combined = 1.056084e-02 	 MSE = 1.056084e-02
# Epoch 593: Combined = 1.050015e-02 	 MSE = 1.050015e-02
# Epoch 594: Combined = 1.167126e-02 	 MSE = 1.167126e-02
# Epoch 595: Combined = 1.302527e-02 	 MSE = 1.302527e-02
# Epoch 596: Combined = 1.579706e-02 	 MSE = 1.579706e-02
# Epoch 597: Combined = 1.714205e-02 	 MSE = 1.714205e-02
# Epoch 598: Combined = 2.079645e-02 	 MSE = 2.079645e-02
# Epoch 599: Combined = 1.727581e-02 	 MSE = 1.727581e-02
# Epoch 600: Combined = 1.615927e-02 	 MSE = 1.615927e-02
# Epoch 601: Combined = 1.287688e-02 	 MSE = 1.287688e-02
# Epoch 602: Combined = 1.028184e-02 	 MSE = 1.028184e-02
# Epoch 603: Combined = 9.944319e-03 	 MSE = 9.944319e-03
# Epoch 604: Combined = 1.042562e-02 	 MSE = 1.042562e-02
# Epoch 605: Combined = 1.133316e-02 	 MSE = 1.133316e-02
# Epoch 606: Combined = 1.216587e-02 	 MSE = 1.216587e-02
# Epoch 607: Combined = 1.220553e-02 	 MSE = 1.220553e-02
# Epoch 608: Combined = 1.123494e-02 	 MSE = 1.123494e-02
# Epoch 609: Combined = 1.062034e-02 	 MSE = 1.062034e-02
# Epoch 610: Combined = 9.483730e-03 	 MSE = 9.483730e-03
# Epoch 611: Combined = 9.134619e-03 	 MSE = 9.134619e-03
# Epoch 612: Combined = 8.972940e-03 	 MSE = 8.972940e-03
# Epoch 613: Combined = 8.947836e-03 	 MSE = 8.947836e-03
# Epoch 614: Combined = 9.486841e-03 	 MSE = 9.486841e-03
# Epoch 615: Combined = 1.000860e-02 	 MSE = 1.000860e-02
# Epoch 616: Combined = 1.217998e-02 	 MSE = 1.217998e-02
# Epoch 617: Combined = 1.749052e-02 	 MSE = 1.749052e-02
# Epoch 618: Combined = 3.564298e-02 	 MSE = 3.564298e-02
# Epoch 619: Combined = 4.775364e-02 	 MSE = 4.775364e-02
# Epoch 620: Combined = 5.133587e-02 	 MSE = 5.133587e-02
# Epoch 621: Combined = 1.187960e-02 	 MSE = 1.187960e-02
# Epoch 622: Combined = 4.403706e-02 	 MSE = 4.403706e-02
# Epoch 623: Combined = 9.902096e-02 	 MSE = 9.902096e-02
# Epoch 624: Combined = 1.178108e-02 	 MSE = 1.178108e-02
# Epoch 625: Combined = 8.986212e-02 	 MSE = 8.986212e-02
# Epoch 626: Combined = 8.759311e-02 	 MSE = 8.759311e-02
# Epoch 627: Combined = 7.992631e-02 	 MSE = 7.992631e-02
# Epoch 628: Combined = 6.810430e-02 	 MSE = 6.810430e-02
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 14
#      12 for epoch in range(1000):
#      13     model.reset_waves()
# ---> 14     v_wdf = model(vin)
#      15     loss = loss_func_train(v_wdf, v_spice)
#      17     optimizer.zero_grad()
#
# File ~/miniconda3/envs/wdf/lib/python3.12/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/wdf/lib/python3.12/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# Cell In[7], line 385, in FuzzStatic.forward(self, vin)
#     383 # Local scattering
#     384 self.b0, self.b1 = self.S_forward @ torch.stack([self.a2, self.a3, self.a4, self.a5])
# --> 385 self.a0, self.a1 = self.nn(torch.stack([self.b0, self.b1]))
#     386 self.b2, self.b3, self.b4 = self.S_backward @ torch.stack([self.a0, self.a1, self.a2, self.a3, self.a4, self.a5])
#     388 # Backward scanning
#
# File ~/miniconda3/envs/wdf/lib/python3.12/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/wdf/lib/python3.12/site-packages/torch/nn/modules/module.py:1513, in Module._call_impl(self, *args, **kwargs)
#    1510     else:
#    1511         return self._call_impl(*args, **kwargs)
# -> 1513 def _call_impl(self, *args, **kwargs):
#    1514     forward_call = (self._slow_forward if torch._C._get_tracing_state() else self.forward)
#    1515     # If we don't have any hooks, we want to skip the rest of the logic in
#    1516     # this function, and just call forward.
#
# KeyboardInterrupt:

# %%
for param_group in optimizer.param_groups:
            param_group['lr'] = param_group['lr'] * 0.1  # 将学习率减少到原来的10%

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=5e-2)
# scheduler = ReduceLROnPlateau(optimizer, factor=0.5, patience=5)

for epoch in range(100):
    model.reset_waves()
    v_wdf = model(vin)
    loss = loss_func_train(v_wdf, v_spice)
    
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    # scheduler.step(loss)
    
    print(f"Epoch {epoch+1}: Combined = {loss.item():.6e} \t MSE = {loss_func_valid(v_wdf, v_spice).item():.6e}")
# Out:
# Epoch 1: Combined = 7.337265e-02 	 MSE = 7.337265e-02
# Epoch 2: Combined = 1.113809e-01 	 MSE = 1.113809e-01
# Epoch 3: Combined = 9.616464e-02 	 MSE = 9.616464e-02
# Epoch 4: Combined = 1.866600e-01 	 MSE = 1.866600e-01
# Epoch 5: Combined = 1.005820e-01 	 MSE = 1.005820e-01
# Epoch 6: Combined = 1.051542e-01 	 MSE = 1.051542e-01
# Epoch 7: Combined = 1.207905e-01 	 MSE = 1.207905e-01
# Epoch 8: Combined = 9.452184e-02 	 MSE = 9.452184e-02
# Epoch 9: Combined = 9.366876e-02 	 MSE = 9.366876e-02
# Epoch 10: Combined = 1.157245e-01 	 MSE = 1.157245e-01
# Epoch 11: Combined = 1.017137e-01 	 MSE = 1.017137e-01
# Epoch 12: Combined = 7.778846e-02 	 MSE = 7.778846e-02
# Epoch 13: Combined = 7.749107e-02 	 MSE = 7.749107e-02
# Epoch 14: Combined = 8.814057e-02 	 MSE = 8.814057e-02
# Epoch 15: Combined = 9.113059e-02 	 MSE = 9.113059e-02
# Epoch 16: Combined = 8.853044e-02 	 MSE = 8.853044e-02
# Epoch 17: Combined = 8.566193e-02 	 MSE = 8.566193e-02
# Epoch 18: Combined = 8.148440e-02 	 MSE = 8.148440e-02
# Epoch 19: Combined = 7.613555e-02 	 MSE = 7.613555e-02
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 10
#       7 loss = loss_func_train(v_wdf, v_spice)
#       9 optimizer.zero_grad()
# ---> 10 loss.backward()
#      11 optimizer.step()
#      12 # scheduler.step(loss)
#
# File ~/miniconda3/envs/wdf/lib/python3.12/site-packages/torch/_tensor.py:522, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     512 if has_torch_function_unary(self):
#     513     return handle_torch_function(
#     514         Tensor.backward,
#     515         (self,),
#    (...)
#     520         inputs=inputs,
#     521     )
# --> 522 torch.autograd.backward(
#     523     self, gradient, retain_graph, create_graph, inputs=inputs
#     524 )
#
# File ~/miniconda3/envs/wdf/lib/python3.12/site-packages/torch/autograd/__init__.py:266, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     261     retain_graph = create_graph
#     263 # The reason we repeat the same comment below is that
#     264 # some Python versions print out the first line of a multi-line function
#     265 # calls in the traceback and some print out the last line
# --> 266 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     267     tensors,
#     268     grad_tensors_,
#     269     retain_graph,
#     270     create_graph,
#     271     inputs,
#     272     allow_unreachable=True,
#     273     accumulate_grad=True,
#     274 )
#
# KeyboardInterrupt:

# %%
torch.set_printoptions(precision=5)
model.nn.linear_relu_stack[0].weight
# Out:
# Parameter containing:
# tensor([[ 0.70064,  0.29991],
#         [-0.00442, -0.11559]], requires_grad=True)

# %%
import matplotlib.pyplot as plt
import numpy as np

figsize = (10, 6)
xlim = (0, 1)

vin, fs = librosa.load("./ltspice/input_fuzz_static.wav", sr=None)
vin = torch.tensor(vin, dtype=torch.float32).unsqueeze(1)
v_spice = librosa.load("./ltspice/output_fuzz_static.wav", sr=None)[0] * 4
v_spice = torch.tensor(v_spice, dtype=torch.float32).unsqueeze(1)

# model = FuzzStatic()
model.reset_waves()
v_wdf = model(vin)

v_wdf_np = v_wdf.detach().numpy().squeeze()
v_spice_np = v_spice.numpy().squeeze()
y_axis = np.linspace(0, v_wdf_np.shape[0] / fs, v_wdf_np.shape[0])

# 创建一个图形和两个子图（ax1 和 ax2）
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=figsize)

# 在第一个子图上绘制原始信号对比
ax1.plot(y_axis, v_spice_np, color="grey", linewidth=3)
ax1.plot(y_axis, v_wdf_np, color="red", linewidth=1)
ax1.set_xlabel("Time (s)")
ax1.set_ylabel("Amplitude")
ax1.set_title("WDF vs LTSpice")
ax1.legend(["LTSpice", "WDF"])
ax1.set_xlim(xlim)
# ax1.set_xticks(np.arange(0, 5.5, 0.5))

# 计算差值信号square error
square_error = (v_spice_np - v_wdf_np) ** 2
MSE = np.mean(square_error)

# 在第二个子图上绘制差值信号图
ax2.plot(y_axis, square_error, color="blue", linewidth=1)
ax2.set_xlabel("Time (s)")
ax2.set_ylabel("Square Error")
ax2.set_title("Square Error Between WDF and Spice")
ax2.set_xlim(xlim)
# ax2.set_xticks(np.arange(0, 5.5, 0.5))

plt.tight_layout()  # 调整子图的间距
plt.show()

print(f"MSE = {MSE:.6e}")
# Out:
# MSE = 4.346816e-02
