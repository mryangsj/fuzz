# %% [markdown]
# ## Import Libraries

# %%
import re
from typing import Tuple

import torch
import h5py
import librosa
from torch import nn
from torch.optim.lr_scheduler import ReduceLROnPlateau

# %% [markdown]
# ## Neural WDF for Two-Port Resistor

# %%
class TwoPortResistorVector(nn.Module):
    def __init__(self, Z: torch.Tensor):
        super(TwoPortResistorVector, self).__init__()
        
        # self.s11 = torch.nn.Parameter(torch.rand(()))
        # self.s12 = torch.nn.Parameter(torch.rand(()))
        # self.s21 = torch.nn.Parameter(torch.rand(()))
        # self.s22 = torch.nn.Parameter(torch.rand(()))

        self.R1 = torch.tensor(23e3)
        self.R2 = torch.tensor(12e3)
        self.R = torch.diag(torch.tensor([self.R1, self.R2]))
        self.Z = Z
        self.Z_inv = torch.inverse(self.Z)
        self.S = torch.inverse(self.R @ self.Z_inv + torch.eye(2)) @ (self.R @ self.Z_inv - torch.eye(2))

    def forward(self, a: torch.Tensor):
        # b1 = x[0, 0] * self.s11 + x[1, 0] * self.s12
        # b2 = x[0, 0] * self.s21 + x[1, 0] * self.s22
        # return torch.stack([b1, b2])

        return self.S @ a

# %% [markdown]
# ## Neural WDF for Fuzz Circuit

# %%
class FuzzStatic(nn.Module):
    def __init__(self, alpha_lin=0.5, alpha_vol=0.5, fs=48e3, s_path="S.hdf5", z_path="Z.hdf5"):
        super(FuzzStatic, self).__init__()
        self.dtype = torch.float64

        # Circuit parameters
        self.C71 = torch.tensor(4.7e-6, dtype=self.dtype)
        self.Rin = torch.tensor(22e3, dtype=self.dtype)
        self.R72 = torch.tensor(50e3, dtype=self.dtype)
        self.C81 = torch.tensor(4.7e-6, dtype=self.dtype)
        self.R81 = torch.tensor(22e3, dtype=self.dtype)
        self.Rout = torch.tensor(100e3, dtype=self.dtype)
        self.C91 = torch.tensor(4.7e-6, dtype=self.dtype)
        self.R_vol = torch.tensor(50e3, dtype=self.dtype)
        self.C94 = torch.tensor(4.7e-6, dtype=self.dtype)


        # User parameters
        self.alpha_lin = alpha_lin
        self.alpha_vol = alpha_vol
        self.fs = fs


        # WDF structure parameters
        self.a_C71 = torch.tensor(-3.7427606943372482, dtype=self.dtype)
        self.a_C81 = torch.tensor(1.8297941172302856, dtype=self.dtype)
        self.a_C91 = torch.tensor(-4.440665733659135e-12, dtype=self.dtype)
        self.a_C94 = torch.tensor(-5.598253191650242, dtype=self.dtype)
        self.b_C71 = torch.tensor(0.0, dtype=self.dtype)
        self.b_C81 = torch.tensor(0.0, dtype=self.dtype)
        self.b_C91 = torch.tensor(0.0, dtype=self.dtype)
        self.b_C94 = torch.tensor(0.0, dtype=self.dtype)

        self.b_S71_0 = torch.tensor(0.0, dtype=self.dtype)
        self.b_P72_0 = torch.tensor(0.0, dtype=self.dtype)
        self.b_P81_0 = torch.tensor(0.0, dtype=self.dtype)
        self.b_S91_0 = torch.tensor(0.0, dtype=self.dtype)
        self.b_P92_0 = torch.tensor(0.0, dtype=self.dtype)
        self.b_S93_0 = torch.tensor(0.0, dtype=self.dtype)
        self.b_S94_0 = torch.tensor(0.0, dtype=self.dtype)
        self.b_S71_1 = torch.tensor(0.0, dtype=self.dtype)
        self.b_P81_1 = torch.tensor(0.0, dtype=self.dtype)
        self.b_S91_1 = torch.tensor(0.0, dtype=self.dtype)
        self.b_S94_1 = torch.tensor(0.0, dtype=self.dtype)
        self.b_P72_2 = torch.tensor(0.0, dtype=self.dtype)
        self.b_P81_2 = torch.tensor(0.0, dtype=self.dtype)
        self.b_S91_2 = torch.tensor(0.0, dtype=self.dtype)
        self.b_P92_2 = torch.tensor(0.0, dtype=self.dtype)
        self.b_S93_2 = torch.tensor(0.0, dtype=self.dtype)
        self.b_S94_2 = torch.tensor(0.0, dtype=self.dtype)

        self.a0 = torch.tensor(0.0, dtype=self.dtype)
        self.a1 = torch.tensor(0.0, dtype=self.dtype)
        self.a2 = torch.tensor(0.0, dtype=self.dtype)
        self.a3 = torch.tensor(0.0, dtype=self.dtype)
        self.a4 = torch.tensor(0.0, dtype=self.dtype)
        self.a5 = torch.tensor(9.0, dtype=self.dtype)
        self.b0 = torch.tensor(0.0, dtype=self.dtype)
        self.b1 = torch.tensor(0.0, dtype=self.dtype)
        self.b2 = torch.tensor(0.0, dtype=self.dtype)
        self.b3 = torch.tensor(0.0, dtype=self.dtype)
        self.b4 = torch.tensor(0.0, dtype=self.dtype)


        # WDF scattering matrices of series and parallel junctions
        self.S_S71, self.S_P72 = self.get_scattering_matrix_port7()
        self.S_P81 = self.get_scattering_matrix_port8()
        self.S_S91, self.S_P92, self.S_S93, self.S_S94 = self.get_scattering_matrix_port9()


        # WDF scattering matrix of the R-type junction
        self.fs_dict = {
            44.1e3 : 0,
            48e3   : 1,
            88.2e3 : 2,
            96e3   : 3,
            176.4e3: 4,
            192e3  : 5
        }
        # STEP 1: Load the scattering and free-parameter impedance matrices from the HDF5 file
        with h5py.File(s_path, "r") as file:
            self.S_matlab = torch.as_tensor(file["/S"][:].T).to(dtype=self.dtype)
        with h5py.File(z_path, "r") as file:
            self.Z_matlab = torch.as_tensor(file["/Z"][:].T).to(dtype=self.dtype)
        # STEP 2: Get the scattering and free-parameter impedance matrices for the given fs, alpha_lin, and alpha_vol
        self.S, self.S_forward, self.S_backward, self.Z, self.Z_root = self.get_scattering_matrix_rtype()
        

        # Initialize two-port resistor
        # self.two_port_resistor = TwoPortResistorVector(self.Z_t)
        self.R1 = torch.tensor(23e3, dtype=self.dtype)
        self.R2 = torch.tensor(12e3, dtype=self.dtype)
        self.R = torch.diag(torch.tensor([self.R1, self.R2]))
        
        self.Z_root_inv = torch.inverse(self.Z_root)
        self.Sr_gt = torch.inverse(self.R @ self.Z_root_inv + torch.eye(2)) @ (self.R @ self.Z_root_inv - torch.eye(2))
        # self.Sr = torch.nn.Parameter(torch.zeros((2, 2), dtype=self.dtype), requires_grad=True)
        self.Sr = torch.nn.Linear(2, 2, bias=False, dtype=self.dtype)


    def get_scattering_matrix_port7(self):
        Z_R71 = self.Rin
        Z_C71 = 1 / (2 * self.fs * self.C71)
        Z_S71 = torch.stack((
            Z_R71 + Z_C71,
            Z_C71,
            Z_R71
        ))

        Z_R72 = self.R72
        Z_P72 = torch.stack((
            (Z_S71[0] * Z_R72) / (Z_S71[0] + Z_R72),
            Z_R72,
            Z_S71[0]
        ))
        return (
            self.get_scattering_matrix_series(Z_S71),
            self.get_scattering_matrix_parallel(Z_P72)
        )


    def get_scattering_matrix_port8(self):
        Z_R81 = self.R81
        Z_C81 = 1 / (2 * self.fs * self.C81)
        Z_P81 = torch.stack((
            (Z_R81 * Z_C81) / (Z_R81 + Z_C81),
            Z_C81,
            Z_R81
        ))
        return self.get_scattering_matrix_parallel(Z_P81)


    def get_scattering_matrix_port9(self):
        Z_R91 = self.Rout
        Z_C91 = 1 / (2 * self.fs * self.C91)
        Z_S91 = torch.stack((
            Z_R91 + Z_C91,
            Z_R91,
            Z_C91
        ))

        R92 = self.alpha_vol * self.R_vol 
        Z_R92 = R92
        Z_P92 = torch.stack((
            (Z_R92 * Z_S91[0]) / (Z_R92 + Z_S91[0]),
            Z_R92,
            Z_S91[0]
        ))        

        R93 = (1 - self.alpha_vol) * self.R_vol
        Z_R93 = R93
        Z_S93 = torch.stack((
            Z_R93 + Z_P92[0],
            Z_R93,
            Z_P92[0]
        ))
        
        Z_C94 = 1 / (2 * self.fs * self.C94)
        Z_S94 = torch.stack((
            Z_C94 + Z_S93[0],
            Z_C94,
            Z_S93[0]
        ))
        
        return (
            self.get_scattering_matrix_series(Z_S91),
            self.get_scattering_matrix_parallel(Z_P92),
            self.get_scattering_matrix_series(Z_S93),
            self.get_scattering_matrix_series(Z_S94)
        )


    def get_scattering_matrix_series(self, Z):
        # STEP 0: Formate the free-parameter impedance matrix Z and get the number of ports
        Z = torch.diag(Z)
        num_ports = Z.shape[0]
        
        # STEP 1: Formulate fundamental loop matrix of the series junction
        B = torch.ones(1, num_ports, dtype=self.dtype)
        
        # STEP 2: Calculate the scattering matrix using the general WD junction method
        I = torch.eye(num_ports, dtype=self.dtype)
        S = I - 2 * Z @ B.T @ torch.inverse(B @ Z @ B.T) @ B
        
        # STEP 3: Return the scattering matrix
        return S


    def get_scattering_matrix_parallel(self, Z):
        # STEP 0: Formate the free-parameter impedance matrix Z and get the number of ports
        Z = torch.diag(Z)
        num_ports = Z.shape[0]
        
        # STEP 1: Formulate fundamental cut-set matrix
        Q = torch.ones(1, num_ports, dtype=self.dtype)
        
        # STEP 2: Calculate the scattering matrix using the general WD junction method
        I = torch.eye(num_ports, dtype=self.dtype)
        Z_inv = torch.inverse(Z)
        S = 2 * Q.T @ torch.inverse(Q @ Z_inv @ Q.T) @ Q @ Z_inv - I
        
        # STEP 3: Return the scattering matrix
        return S


    def get_scattering_matrix_rtype(self):
        fs_index = self.fs_dict[self.fs]
        alpha_lin_index = round(self.alpha_lin * 100)
        alpha_vol_index = round(self.alpha_vol * 100)

        S = self.S_matlab[fs_index, alpha_lin_index, alpha_vol_index, :, :]
        S_forward = S[0:2, 6:10]
        S_backward = torch.cat((S[6:9, 0:2], S[6:9, 6:10]), dim=1)

        Z = self.Z_matlab[fs_index, alpha_lin_index, alpha_vol_index, :, :]
        Z_root = Z[0:2, 0:2]

        return (
            S,
            S_forward,
            S_backward,
            Z,
            Z_root
        )


    def reset_waves(self):
        self.a_C71 = torch.tensor(-3.7427606943372482, dtype=self.dtype)
        self.a_C81 = torch.tensor(1.8297941172302856, dtype=self.dtype)
        self.a_C91 = torch.tensor(-4.440665733659135e-12, dtype=self.dtype)
        self.a_C94 = torch.tensor(-5.598253191650242, dtype=self.dtype)
        self.b_C71 = torch.tensor(0.0, dtype=self.dtype)
        self.b_C81 = torch.tensor(0.0, dtype=self.dtype)
        self.b_C91 = torch.tensor(0.0, dtype=self.dtype)
        self.b_C94 = torch.tensor(0.0, dtype=self.dtype)

        self.b_S71_0 = torch.tensor(0.0, dtype=self.dtype)
        self.b_P72_0 = torch.tensor(0.0, dtype=self.dtype)
        self.b_P81_0 = torch.tensor(0.0, dtype=self.dtype)
        self.b_S91_0 = torch.tensor(0.0, dtype=self.dtype)
        self.b_P92_0 = torch.tensor(0.0, dtype=self.dtype)
        self.b_S93_0 = torch.tensor(0.0, dtype=self.dtype)
        self.b_S94_0 = torch.tensor(0.0, dtype=self.dtype)
        self.b_S71_1 = torch.tensor(0.0, dtype=self.dtype)
        self.b_P81_1 = torch.tensor(0.0, dtype=self.dtype)
        self.b_S91_1 = torch.tensor(0.0, dtype=self.dtype)
        self.b_S94_1 = torch.tensor(0.0, dtype=self.dtype)
        self.b_P72_2 = torch.tensor(0.0, dtype=self.dtype)
        self.b_P81_2 = torch.tensor(0.0, dtype=self.dtype)
        self.b_S91_2 = torch.tensor(0.0, dtype=self.dtype)
        self.b_P92_2 = torch.tensor(0.0, dtype=self.dtype)
        self.b_S93_2 = torch.tensor(0.0, dtype=self.dtype)
        self.b_S94_2 = torch.tensor(0.0, dtype=self.dtype)

        self.a0 = torch.tensor(0.0, dtype=self.dtype)
        self.a1 = torch.tensor(0.0, dtype=self.dtype)
        self.a2 = torch.tensor(0.0, dtype=self.dtype)
        self.a3 = torch.tensor(0.0, dtype=self.dtype)
        self.a4 = torch.tensor(0.0, dtype=self.dtype)
        self.a5 = torch.tensor(9.0, dtype=self.dtype)
        self.b0 = torch.tensor(0.0, dtype=self.dtype)
        self.b1 = torch.tensor(0.0, dtype=self.dtype)
        self.b2 = torch.tensor(0.0, dtype=self.dtype)
        self.b3 = torch.tensor(0.0, dtype=self.dtype)
        self.b4 = torch.tensor(0.0, dtype=self.dtype)


    def solve_dc(self, dc_in=0.0, epsilon=1e-10):
        # STEP 0: Reset the waves to DC=0 state
        self.a_C71 = torch.tensor(-3.7427606943372482, dtype=self.dtype)
        self.a_C81 = torch.tensor(1.8297941172302856, dtype=self.dtype)
        self.a_C91 = torch.tensor(-4.440665733659135e-12, dtype=self.dtype)
        self.a_C94 = torch.tensor(-5.598253191650242, dtype=self.dtype)
        # Check if the input is DC=0
        if dc_in == 0.0:
            return self.a_C71, self.a_C81, self.a_C91, self.a_C94

        # STEP 1: Prepare the WDF structure for the DC analysis
        is_stable = False
        error_eps = epsilon

        # STEP 2: Iterate the WDF structure until the states of capacitors and inductors are stable
        ii = 0
        while not is_stable:
            ii += 1

            # Manage capacitors and inductors' states
            self.b_C71 = self.a_C71
            self.b_C81 = self.a_C81
            self.b_C91 = self.a_C91
            self.b_C94 = self.a_C94

            # Forward scanning
            self.b_S71_0 = self.S_S71[0, 1] * self.b_C71 + self.S_S71[0, 2] * dc_in
            self.b_P72_0 = self.S_P72[0, 2] * self.b_S71_0
            self.b_P81_0 = self.S_P81[0, 1] * self.b_C81
            self.b_S91_0 = self.S_S91[0, 2] * self.b_C91
            self.b_P92_0 = self.S_P92[0, 2] * self.b_S91_0
            self.b_S93_0 = self.S_S93[0, 2] * self.b_P92_0
            self.b_S94_0 = self.S_S94[0, 1] * self.b_C94 + self.S_S94[0, 2] * self.b_S93_0
            
            self.a2 = self.b_P72_0
            self.a3 = self.b_P81_0
            self.a4 = self.b_S94_0

            # Local scattering
            self.b0, self.b1 = self.S_forward @ torch.stack([self.a2, self.a3, self.a4, self.a5])
            self.a0, self.a1 = self.Sr_gt @ torch.stack([self.b0, self.b1])
            # self.a0, self.a1 = self.Sr(torch.stack([self.b0, self.b1]))
            self.b2, self.b3, self.b4 = self.S_backward @ torch.stack([self.a0, self.a1, self.a2, self.a3, self.a4, self.a5])

            # Backward scanning
            self.b_P72_2 = self.S_P72[2, 0] * self.b2 + self.S_P72[2, 2] * self.b_S71_0
            self.b_S71_1 = self.S_S71[1, 0] * self.b_P72_2 + self.S_S71[1, 1] * self.b_C71 + self.S_S71[1, 2] * dc_in
            self.b_P81_1 = self.S_P81[1, 0] * self.b3 + self.S_P81[1, 1] * self.b_C81
            self.b_S94_1, self.b_S94_2 = self.S_S94[1:3, :] @ torch.stack([self.b4, self.b_C94, self.b_S93_0])
            self.b_S93_2 = self.S_S93[2, 0] * self.b_S94_2 + self.S_S93[2, 2] * self.b_P92_0
            self.b_P92_2 = self.S_P92[2, 0] * self.b_S93_2 + self.S_P92[2, 2] * self.b_S91_0
            self.b_S91_2 = self.S_S91[2, 0] * self.b_P92_2 + self.S_S91[2, 2] * self.b_C91

            # Check if the states of capacitors and inductors are stable
            if (
                torch.abs(self.b_C71 - self.b_S71_1) > error_eps
                or torch.abs(self.b_C81 - self.b_P81_1) > error_eps
                or torch.abs(self.b_C91 - self.b_S91_2) > error_eps
                or torch.abs(self.b_C94 - self.b_S94_1) > error_eps
            ):
                self.a_C71 = self.b_S71_1
                self.a_C81 = self.b_P81_1
                self.a_C91 = self.b_S91_2
                self.a_C94 = self.b_S94_1
            else:
                is_stable = True

        print("Iterations:", ii)
        print(
            "Stable states:\n  C71:",
            self.a_C71,
            "\n  C81:",
            self.a_C81,
            "\n  C91:",
            self.a_C91,
            "\n  C94:",
            self.a_C94,
        )

        return self.a_C71, self.a_C81, self.a_C91, self.a_C94


    def set_capacitors_initial_states(self, C71, C81, C91, C94):
        self.a_C71 = C71
        self.a_C81 = C81
        self.a_C91 = C91
        self.a_C94 = C94


    def forward(self, vin):
        vout = torch.zeros_like(vin)

        for i in range(vin.shape[0]):
            # Manage capacitors and inductors' states
            self.b_C71 = self.a_C71
            self.b_C81 = self.a_C81
            self.b_C91 = self.a_C91
            self.b_C94 = self.a_C94

            # Forward scanning
            self.b_S71_0 = self.S_S71[0, 1] * self.b_C71 + self.S_S71[0, 2] * vin[i, 0]
            self.b_P72_0 = self.S_P72[0, 2] * self.b_S71_0
            self.b_P81_0 = self.S_P81[0, 1] * self.b_C81
            self.b_S91_0 = self.S_S91[0, 2] * self.b_C91
            self.b_P92_0 = self.S_P92[0, 2] * self.b_S91_0
            self.b_S93_0 = self.S_S93[0, 2] * self.b_P92_0
            self.b_S94_0 = self.S_S94[0, 1] * self.b_C94 + self.S_S94[0, 2] * self.b_S93_0
            
            self.a2 = self.b_P72_0
            self.a3 = self.b_P81_0
            self.a4 = self.b_S94_0

            # Local scattering
            self.b0, self.b1 = self.S_forward @ torch.stack([self.a2, self.a3, self.a4, self.a5])
            self.a0, self.a1 = self.Sr_gt @ torch.stack([self.b0, self.b1])
            # self.a0, self.a1 = self.Sr(torch.stack([self.b0, self.b1]))
            self.b2, self.b3, self.b4 = self.S_backward @ torch.stack([self.a0, self.a1, self.a2, self.a3, self.a4, self.a5])
            
            # Backward scanning
            self.b_P72_2 = self.S_P72[2, 0] * self.b2 + self.S_P72[2, 2] * self.b_S71_0
            self.b_S71_1 = self.S_S71[1, 0] * self.b_P72_2 + self.S_S71[1, 1] * self.b_C71 + self.S_S71[1, 2] * vin[i, 0]
            self.b_P81_1 = self.S_P81[1, 0] * self.b3 + self.S_P81[1, 1] * self.b_C81
            self.b_S94_1, self.b_S94_2 = self.S_S94[1:3, :] @ torch.stack([self.b4, self.b_C94, self.b_S93_0])
            self.b_S93_2 = self.S_S93[2, 0] * self.b_S94_2 + self.S_S93[2, 2] * self.b_P92_0
            self.b_P92_2 = self.S_P92[2, 0] * self.b_S93_2 + self.S_P92[2, 2] * self.b_S91_0
            self.b_S91_1 = self.S_S91[1, 0] * self.b_P92_2 + self.S_S91[1, 2] * self.b_C91
            self.b_S91_2 = self.S_S91[2, 0] * self.b_P92_2 + self.S_S91[2, 2] * self.b_C91
            
            self.a_C71 = self.b_S71_1
            self.a_C81 = self.b_P81_1
            self.a_C91 = self.b_S91_2
            self.a_C94 = self.b_S94_1
            
            vout[i, 0] = self.b_S91_1 / 2
        
        return vout


# vin, fs = librosa.load("./matlab/input_fuzz_static.wav", sr=None)
# vin = torch.tensor(vin, dtype=torch.float32).unsqueeze(1)

# model = FuzzStatic()
# model.init_waves()
# v_wdf = model(vin)

# %% [markdown]
# ## Loss Function

# %%
class ESRLoss(nn.Module):
    def __init__(self):
        super(ESRLoss, self).__init__()

    def forward(self, y_true, y_pred):
        return torch.sum((y_true - y_pred)**2) / torch.sum(y_true**2)
    
class DCLoss(nn.Module):
    def __init__(self):
        super(DCLoss, self).__init__()

    def forward(self, y_true, y_pred):
        numerator = torch.abs(torch.mean(y_true - y_pred))**2
        denominator = torch.mean(y_true ** 2)
        return numerator / denominator

class CombinedSignalLoss(nn.Module):
    def __init__(self):
        super().__init__()

    def forward(self, y_target, y_pred):
        diff = y_target - y_pred
        diff2 = diff ** 2
        y_energy = y_target ** 2
        
        loss_mse = torch.mean(diff2)
        loss_esr = torch.sum(diff2) / torch.sum(y_energy)
        loss_dc = torch.abs(torch.mean(diff))**2 / torch.mean(y_energy)
        return loss_mse + loss_esr + loss_dc

# %% [markdown]
# ## Training Loop

# %%
vin, fs = librosa.load("./ltspice/input_fuzz_static.wav", sr=None)
vin = torch.tensor(vin, dtype=torch.float32).unsqueeze(1)
v_spice = librosa.load("./ltspice/output_fuzz_static.wav", sr=None)[0]
v_spice = torch.tensor(v_spice, dtype=torch.float32).unsqueeze(1)

model = FuzzStatic()
loss_func_train = nn.MSELoss()
loss_func_valid = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-1)
# scheduler = ReduceLROnPlateau(optimizer, factor=0.5, patience=5)
# torch.autograd.set_detect_anomaly(True)

for epoch in range(400):
    model.reset_waves()
    model.solve_dc(vin[0, 0])
    v_wdf = model(vin)
    loss = loss_func_train(v_wdf, v_spice)
    
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    # scheduler.step(loss)
    
    print(f"Epoch {epoch+1}: Combined = {loss.item():.6e} \t MSE = {loss_func_valid(v_wdf, v_spice).item():.6e}")
# Out:
# Epoch 1: Combined = 2.318030e-02 	 MSE = 2.318030e-02
# Epoch 2: Combined = 5.143870e-04 	 MSE = 5.143870e-04
# Epoch 3: Combined = 1.055413e-02 	 MSE = 1.055413e-02
# Epoch 4: Combined = 9.750941e-03 	 MSE = 9.750941e-03
# Epoch 5: Combined = 2.720027e-03 	 MSE = 2.720027e-03
# Epoch 6: Combined = 5.593654e-04 	 MSE = 5.593654e-04
# Epoch 7: Combined = 2.732597e-03 	 MSE = 2.732597e-03
# Epoch 8: Combined = 5.256313e-03 	 MSE = 5.256313e-03
# Epoch 9: Combined = 5.765450e-03 	 MSE = 5.765450e-03
# Epoch 10: Combined = 4.304801e-03 	 MSE = 4.304801e-03
# Epoch 11: Combined = 2.236252e-03 	 MSE = 2.236252e-03
# Epoch 12: Combined = 1.036094e-03 	 MSE = 1.036094e-03
# Epoch 13: Combined = 1.353808e-03 	 MSE = 1.353808e-03
# Epoch 14: Combined = 2.503517e-03 	 MSE = 2.503517e-03
# Epoch 15: Combined = 3.031710e-03 	 MSE = 3.031710e-03
# Epoch 16: Combined = 2.243162e-03 	 MSE = 2.243162e-03
# Epoch 17: Combined = 8.812166e-04 	 MSE = 8.812166e-04
# Epoch 18: Combined = 1.482321e-04 	 MSE = 1.482321e-04
# Epoch 19: Combined = 4.634364e-04 	 MSE = 4.634364e-04
# Epoch 20: Combined = 1.213040e-03 	 MSE = 1.213040e-03
# Epoch 21: Combined = 1.492247e-03 	 MSE = 1.492247e-03
# Epoch 22: Combined = 1.001304e-03 	 MSE = 1.001304e-03
# Epoch 23: Combined = 2.651716e-04 	 MSE = 2.651716e-04
# Epoch 24: Combined = 5.600473e-05 	 MSE = 5.600473e-05
# Epoch 25: Combined = 5.288775e-04 	 MSE = 5.288775e-04
# Epoch 26: Combined = 9.832508e-04 	 MSE = 9.832508e-04
# Epoch 27: Combined = 7.968941e-04 	 MSE = 7.968941e-04
# Epoch 28: Combined = 2.720409e-04 	 MSE = 2.720409e-04
# Epoch 29: Combined = 7.350757e-05 	 MSE = 7.350757e-05
# Epoch 30: Combined = 3.140966e-04 	 MSE = 3.140966e-04
# Epoch 31: Combined = 5.640187e-04 	 MSE = 5.640187e-04
# Epoch 32: Combined = 4.831925e-04 	 MSE = 4.831925e-04
# Epoch 33: Combined = 1.810506e-04 	 MSE = 1.810506e-04
# Epoch 34: Combined = 4.285904e-06 	 MSE = 4.285904e-06
# Epoch 35: Combined = 1.048334e-04 	 MSE = 1.048334e-04
# Epoch 36: Combined = 2.864882e-04 	 MSE = 2.864882e-04
# Epoch 37: Combined = 2.926354e-04 	 MSE = 2.926354e-04
# Epoch 38: Combined = 1.345742e-04 	 MSE = 1.345742e-04
# Epoch 39: Combined = 2.360210e-05 	 MSE = 2.360210e-05
# Epoch 40: Combined = 7.197359e-05 	 MSE = 7.197359e-05
# Epoch 41: Combined = 1.832994e-04 	 MSE = 1.832994e-04
# Epoch 42: Combined = 2.075445e-04 	 MSE = 2.075445e-04
# Epoch 43: Combined = 1.214228e-04 	 MSE = 1.214228e-04
# Epoch 44: Combined = 3.355432e-05 	 MSE = 3.355432e-05
# Epoch 45: Combined = 3.840714e-05 	 MSE = 3.840714e-05
# Epoch 46: Combined = 1.018961e-04 	 MSE = 1.018961e-04
# Epoch 47: Combined = 1.186190e-04 	 MSE = 1.186190e-04
# Epoch 48: Combined = 6.031561e-05 	 MSE = 6.031561e-05
# Epoch 49: Combined = 5.033746e-06 	 MSE = 5.033746e-06
# Epoch 50: Combined = 1.651938e-05 	 MSE = 1.651938e-05
# Epoch 51: Combined = 6.067190e-05 	 MSE = 6.067190e-05
# Epoch 52: Combined = 6.701316e-05 	 MSE = 6.701316e-05
# Epoch 53: Combined = 2.926693e-05 	 MSE = 2.926693e-05
# Epoch 54: Combined = 4.289337e-06 	 MSE = 4.289337e-06
# Epoch 55: Combined = 2.325671e-05 	 MSE = 2.325671e-05
# Epoch 56: Combined = 4.915181e-05 	 MSE = 4.915181e-05
# Epoch 57: Combined = 3.990105e-05 	 MSE = 3.990105e-05
# Epoch 58: Combined = 1.189620e-05 	 MSE = 1.189620e-05
# Epoch 59: Combined = 5.935236e-06 	 MSE = 5.935236e-06
# Epoch 60: Combined = 2.254623e-05 	 MSE = 2.254623e-05
# Epoch 61: Combined = 2.916294e-05 	 MSE = 2.916294e-05
# Epoch 62: Combined = 1.426899e-05 	 MSE = 1.426899e-05
# Epoch 63: Combined = 6.544620e-07 	 MSE = 6.544620e-07
# Epoch 64: Combined = 5.957780e-06 	 MSE = 5.957780e-06
# Epoch 65: Combined = 1.707995e-05 	 MSE = 1.707995e-05
# Epoch 66: Combined = 1.491703e-05 	 MSE = 1.491703e-05
# Epoch 67: Combined = 4.343427e-06 	 MSE = 4.343427e-06
# Epoch 68: Combined = 2.343879e-06 	 MSE = 2.343879e-06
# Epoch 69: Combined = 9.738784e-06 	 MSE = 9.738784e-06
# Epoch 70: Combined = 1.277838e-05 	 MSE = 1.277838e-05
# Epoch 71: Combined = 6.649754e-06 	 MSE = 6.649754e-06
# Epoch 72: Combined = 1.358898e-06 	 MSE = 1.358898e-06
# Epoch 73: Combined = 3.863500e-06 	 MSE = 3.863500e-06
# Epoch 74: Combined = 7.661426e-06 	 MSE = 7.661426e-06
# Epoch 75: Combined = 5.342665e-06 	 MSE = 5.342665e-06
# Epoch 76: Combined = 7.760447e-07 	 MSE = 7.760447e-07
# Epoch 77: Combined = 1.030045e-06 	 MSE = 1.030045e-06
# Epoch 78: Combined = 4.316021e-06 	 MSE = 4.316021e-06
# Epoch 79: Combined = 4.374509e-06 	 MSE = 4.374509e-06
# Epoch 80: Combined = 1.444182e-06 	 MSE = 1.444182e-06
# Epoch 81: Combined = 7.288537e-07 	 MSE = 7.288537e-07
# Epoch 82: Combined = 2.841554e-06 	 MSE = 2.841554e-06
# Epoch 83: Combined = 3.473633e-06 	 MSE = 3.473633e-06
# Epoch 84: Combined = 1.515732e-06 	 MSE = 1.515732e-06
# Epoch 85: Combined = 4.205923e-07 	 MSE = 4.205923e-07
# Epoch 86: Combined = 1.529755e-06 	 MSE = 1.529755e-06
# Epoch 87: Combined = 2.189721e-06 	 MSE = 2.189721e-06
# Epoch 88: Combined = 1.041694e-06 	 MSE = 1.041694e-06
# Epoch 89: Combined = 1.467756e-07 	 MSE = 1.467756e-07
# Epoch 90: Combined = 8.327910e-07 	 MSE = 8.327910e-07
# Epoch 91: Combined = 1.501178e-06 	 MSE = 1.501178e-06
# Epoch 92: Combined = 9.091007e-07 	 MSE = 9.091007e-07
# Epoch 93: Combined = 2.698156e-07 	 MSE = 2.698156e-07
# Epoch 94: Combined = 6.612332e-07 	 MSE = 6.612332e-07
# Epoch 95: Combined = 1.131526e-06 	 MSE = 1.131526e-06
# Epoch 96: Combined = 7.399350e-07 	 MSE = 7.399350e-07
# Epoch 97: Combined = 2.330501e-07 	 MSE = 2.330501e-07
# Epoch 98: Combined = 4.264548e-07 	 MSE = 4.264548e-07
# Epoch 99: Combined = 7.334045e-07 	 MSE = 7.334045e-07
# Epoch 100: Combined = 4.782294e-07 	 MSE = 4.782294e-07
# Epoch 101: Combined = 1.514849e-07 	 MSE = 1.514849e-07
# Epoch 102: Combined = 3.107083e-07 	 MSE = 3.107083e-07
# Epoch 103: Combined = 5.396961e-07 	 MSE = 5.396961e-07
# Epoch 104: Combined = 3.802527e-07 	 MSE = 3.802527e-07
# Epoch 105: Combined = 1.812451e-07 	 MSE = 1.812451e-07
# Epoch 106: Combined = 3.021168e-07 	 MSE = 3.021168e-07
# Epoch 107: Combined = 4.336779e-07 	 MSE = 4.336779e-07
# Epoch 108: Combined = 2.950156e-07 	 MSE = 2.950156e-07
# Epoch 109: Combined = 1.612164e-07 	 MSE = 1.612164e-07
# Epoch 110: Combined = 2.474210e-07 	 MSE = 2.474210e-07
# Epoch 111: Combined = 3.146621e-07 	 MSE = 3.146621e-07
# Epoch 112: Combined = 2.092607e-07 	 MSE = 2.092607e-07
# Epoch 113: Combined = 1.430213e-07 	 MSE = 1.430213e-07
# Epoch 114: Combined = 2.217066e-07 	 MSE = 2.217066e-07
# Epoch 115: Combined = 2.580227e-07 	 MSE = 2.580227e-07
# Epoch 116: Combined = 1.832313e-07 	 MSE = 1.832313e-07
# Epoch 117: Combined = 1.571327e-07 	 MSE = 1.571327e-07
# Epoch 118: Combined = 2.142624e-07 	 MSE = 2.142624e-07
# Epoch 119: Combined = 2.179265e-07 	 MSE = 2.179265e-07
# Epoch 120: Combined = 1.589959e-07 	 MSE = 1.589959e-07
# Epoch 121: Combined = 1.524134e-07 	 MSE = 1.524134e-07
# Epoch 122: Combined = 1.895073e-07 	 MSE = 1.895073e-07
# Epoch 123: Combined = 1.781934e-07 	 MSE = 1.781934e-07
# Epoch 124: Combined = 1.419144e-07 	 MSE = 1.419144e-07
# Epoch 125: Combined = 1.523595e-07 	 MSE = 1.523595e-07
# Epoch 126: Combined = 1.765184e-07 	 MSE = 1.765184e-07
# Epoch 127: Combined = 1.608538e-07 	 MSE = 1.608538e-07
# Epoch 128: Combined = 1.421482e-07 	 MSE = 1.421482e-07
# Epoch 129: Combined = 1.562289e-07 	 MSE = 1.562289e-07
# Epoch 130: Combined = 1.649520e-07 	 MSE = 1.649520e-07
# Epoch 131: Combined = 1.472959e-07 	 MSE = 1.472959e-07
# Epoch 132: Combined = 1.397349e-07 	 MSE = 1.397349e-07
# Epoch 133: Combined = 1.515609e-07 	 MSE = 1.515609e-07
# Epoch 134: Combined = 1.510633e-07 	 MSE = 1.510633e-07
# Epoch 135: Combined = 1.386135e-07 	 MSE = 1.386135e-07
# Epoch 136: Combined = 1.401532e-07 	 MSE = 1.401532e-07
# Epoch 137: Combined = 1.485041e-07 	 MSE = 1.485041e-07
# Epoch 138: Combined = 1.439364e-07 	 MSE = 1.439364e-07
# Epoch 139: Combined = 1.373524e-07 	 MSE = 1.373524e-07
# Epoch 140: Combined = 1.416977e-07 	 MSE = 1.416977e-07
# Epoch 141: Combined = 1.442804e-07 	 MSE = 1.442804e-07
# Epoch 142: Combined = 1.382019e-07 	 MSE = 1.382019e-07
# Epoch 143: Combined = 1.360668e-07 	 MSE = 1.360668e-07
# Epoch 144: Combined = 1.399180e-07 	 MSE = 1.399180e-07
# Epoch 145: Combined = 1.389246e-07 	 MSE = 1.389246e-07
# Epoch 146: Combined = 1.348865e-07 	 MSE = 1.348865e-07
# Epoch 147: Combined = 1.360892e-07 	 MSE = 1.360892e-07
# Epoch 148: Combined = 1.382511e-07 	 MSE = 1.382511e-07
# Epoch 149: Combined = 1.358841e-07 	 MSE = 1.358841e-07
# Epoch 150: Combined = 1.342551e-07 	 MSE = 1.342551e-07
# Epoch 151: Combined = 1.359787e-07 	 MSE = 1.359787e-07
# Epoch 152: Combined = 1.358066e-07 	 MSE = 1.358066e-07
# Epoch 153: Combined = 1.335134e-07 	 MSE = 1.335134e-07
# Epoch 154: Combined = 1.335474e-07 	 MSE = 1.335474e-07
# Epoch 155: Combined = 1.345097e-07 	 MSE = 1.345097e-07
# Epoch 156: Combined = 1.333224e-07 	 MSE = 1.333224e-07
# Epoch 157: Combined = 1.323136e-07 	 MSE = 1.323136e-07
# Epoch 158: Combined = 1.330803e-07 	 MSE = 1.330803e-07
# Epoch 159: Combined = 1.330450e-07 	 MSE = 1.330450e-07
# Epoch 160: Combined = 1.318850e-07 	 MSE = 1.318850e-07
# Epoch 161: Combined = 1.318109e-07 	 MSE = 1.318109e-07
# Epoch 162: Combined = 1.321675e-07 	 MSE = 1.321675e-07
# Epoch 163: Combined = 1.314257e-07 	 MSE = 1.314257e-07
# Epoch 164: Combined = 1.307891e-07 	 MSE = 1.307891e-07
# Epoch 165: Combined = 1.310194e-07 	 MSE = 1.310194e-07
# Epoch 166: Combined = 1.308192e-07 	 MSE = 1.308192e-07
# Epoch 167: Combined = 1.301413e-07 	 MSE = 1.301413e-07
# Epoch 168: Combined = 1.300639e-07 	 MSE = 1.300639e-07
# Epoch 169: Combined = 1.301250e-07 	 MSE = 1.301250e-07
# Epoch 170: Combined = 1.296365e-07 	 MSE = 1.296365e-07
# Epoch 171: Combined = 1.292814e-07 	 MSE = 1.292814e-07
# Epoch 172: Combined = 1.292975e-07 	 MSE = 1.292975e-07
# Epoch 173: Combined = 1.290152e-07 	 MSE = 1.290152e-07
# Epoch 174: Combined = 1.285678e-07 	 MSE = 1.285678e-07
# Epoch 175: Combined = 1.284481e-07 	 MSE = 1.284481e-07
# Epoch 176: Combined = 1.283131e-07 	 MSE = 1.283131e-07
# Epoch 177: Combined = 1.279327e-07 	 MSE = 1.279327e-07
# Epoch 178: Combined = 1.277008e-07 	 MSE = 1.277008e-07
# Epoch 179: Combined = 1.276015e-07 	 MSE = 1.276015e-07
# Epoch 180: Combined = 1.273145e-07 	 MSE = 1.273145e-07
# Epoch 181: Combined = 1.270130e-07 	 MSE = 1.270130e-07
# Epoch 182: Combined = 1.268664e-07 	 MSE = 1.268664e-07
# Epoch 183: Combined = 1.266443e-07 	 MSE = 1.266443e-07
# Epoch 184: Combined = 1.263337e-07 	 MSE = 1.263337e-07
# Epoch 185: Combined = 1.261335e-07 	 MSE = 1.261335e-07
# Epoch 186: Combined = 1.259492e-07 	 MSE = 1.259492e-07
# Epoch 187: Combined = 1.256711e-07 	 MSE = 1.256711e-07
# Epoch 188: Combined = 1.254364e-07 	 MSE = 1.254364e-07
# Epoch 189: Combined = 1.252563e-07 	 MSE = 1.252563e-07
# Epoch 190: Combined = 1.250099e-07 	 MSE = 1.250099e-07
# Epoch 191: Combined = 1.247549e-07 	 MSE = 1.247549e-07
# Epoch 192: Combined = 1.245564e-07 	 MSE = 1.245564e-07
# Epoch 193: Combined = 1.243298e-07 	 MSE = 1.243298e-07
# Epoch 194: Combined = 1.240726e-07 	 MSE = 1.240726e-07
# Epoch 195: Combined = 1.238566e-07 	 MSE = 1.238566e-07
# Epoch 196: Combined = 1.236423e-07 	 MSE = 1.236423e-07
# Epoch 197: Combined = 1.233949e-07 	 MSE = 1.233949e-07
# Epoch 198: Combined = 1.231675e-07 	 MSE = 1.231675e-07
# Epoch 199: Combined = 1.229551e-07 	 MSE = 1.229551e-07
# Epoch 200: Combined = 1.227168e-07 	 MSE = 1.227168e-07
# Epoch 201: Combined = 1.224811e-07 	 MSE = 1.224811e-07
# Epoch 202: Combined = 1.222637e-07 	 MSE = 1.222637e-07
# Epoch 203: Combined = 1.220316e-07 	 MSE = 1.220316e-07
# Epoch 204: Combined = 1.217934e-07 	 MSE = 1.217934e-07
# Epoch 205: Combined = 1.215711e-07 	 MSE = 1.215711e-07
# Epoch 206: Combined = 1.213438e-07 	 MSE = 1.213438e-07
# Epoch 207: Combined = 1.211071e-07 	 MSE = 1.211071e-07
# Epoch 208: Combined = 1.208807e-07 	 MSE = 1.208807e-07
# Epoch 209: Combined = 1.206550e-07 	 MSE = 1.206550e-07
# Epoch 210: Combined = 1.204199e-07 	 MSE = 1.204199e-07
# Epoch 211: Combined = 1.201898e-07 	 MSE = 1.201898e-07
# Epoch 212: Combined = 1.199633e-07 	 MSE = 1.199633e-07
# Epoch 213: Combined = 1.197297e-07 	 MSE = 1.197297e-07
# Epoch 214: Combined = 1.194978e-07 	 MSE = 1.194978e-07
# Epoch 215: Combined = 1.192703e-07 	 MSE = 1.192703e-07
# Epoch 216: Combined = 1.190383e-07 	 MSE = 1.190383e-07
# Epoch 217: Combined = 1.188058e-07 	 MSE = 1.188058e-07
# Epoch 218: Combined = 1.185770e-07 	 MSE = 1.185770e-07
# Epoch 219: Combined = 1.183458e-07 	 MSE = 1.183458e-07
# Epoch 220: Combined = 1.181127e-07 	 MSE = 1.181127e-07
# Epoch 221: Combined = 1.178825e-07 	 MSE = 1.178825e-07
# Epoch 222: Combined = 1.176514e-07 	 MSE = 1.176514e-07
# Epoch 223: Combined = 1.174182e-07 	 MSE = 1.174182e-07
# Epoch 224: Combined = 1.171871e-07 	 MSE = 1.171871e-07
# Epoch 225: Combined = 1.169559e-07 	 MSE = 1.169559e-07
# Epoch 226: Combined = 1.167229e-07 	 MSE = 1.167229e-07
# Epoch 227: Combined = 1.164911e-07 	 MSE = 1.164911e-07
# Epoch 228: Combined = 1.162596e-07 	 MSE = 1.162596e-07
# Epoch 229: Combined = 1.160266e-07 	 MSE = 1.160266e-07
# Epoch 230: Combined = 1.157942e-07 	 MSE = 1.157942e-07
# Epoch 231: Combined = 1.155623e-07 	 MSE = 1.155623e-07
# Epoch 232: Combined = 1.153293e-07 	 MSE = 1.153293e-07
# Epoch 233: Combined = 1.150965e-07 	 MSE = 1.150965e-07
# Epoch 234: Combined = 1.148642e-07 	 MSE = 1.148642e-07
# Epoch 235: Combined = 1.146312e-07 	 MSE = 1.146312e-07
# Epoch 236: Combined = 1.143981e-07 	 MSE = 1.143981e-07
# Epoch 237: Combined = 1.141655e-07 	 MSE = 1.141655e-07
# Epoch 238: Combined = 1.139324e-07 	 MSE = 1.139324e-07
# Epoch 239: Combined = 1.136991e-07 	 MSE = 1.136991e-07
# Epoch 240: Combined = 1.134661e-07 	 MSE = 1.134661e-07
# Epoch 241: Combined = 1.132329e-07 	 MSE = 1.132329e-07
# Epoch 242: Combined = 1.129994e-07 	 MSE = 1.129994e-07
# Epoch 243: Combined = 1.127662e-07 	 MSE = 1.127662e-07
# Epoch 244: Combined = 1.125328e-07 	 MSE = 1.125328e-07
# Epoch 245: Combined = 1.122992e-07 	 MSE = 1.122992e-07
# Epoch 246: Combined = 1.120658e-07 	 MSE = 1.120658e-07
# Epoch 247: Combined = 1.118323e-07 	 MSE = 1.118323e-07
# Epoch 248: Combined = 1.115986e-07 	 MSE = 1.115986e-07
# Epoch 249: Combined = 1.113651e-07 	 MSE = 1.113651e-07
# Epoch 250: Combined = 1.111314e-07 	 MSE = 1.111314e-07
# Epoch 251: Combined = 1.108977e-07 	 MSE = 1.108977e-07
# Epoch 252: Combined = 1.106640e-07 	 MSE = 1.106640e-07
# Epoch 253: Combined = 1.104302e-07 	 MSE = 1.104302e-07
# Epoch 254: Combined = 1.101964e-07 	 MSE = 1.101964e-07
# Epoch 255: Combined = 1.099627e-07 	 MSE = 1.099627e-07
# Epoch 256: Combined = 1.097289e-07 	 MSE = 1.097289e-07
# Epoch 257: Combined = 1.094950e-07 	 MSE = 1.094950e-07
# Epoch 258: Combined = 1.092612e-07 	 MSE = 1.092612e-07
# Epoch 259: Combined = 1.090273e-07 	 MSE = 1.090273e-07
# Epoch 260: Combined = 1.087935e-07 	 MSE = 1.087935e-07
# Epoch 261: Combined = 1.085596e-07 	 MSE = 1.085596e-07
# Epoch 262: Combined = 1.083258e-07 	 MSE = 1.083258e-07
# Epoch 263: Combined = 1.080919e-07 	 MSE = 1.080919e-07
# Epoch 264: Combined = 1.078580e-07 	 MSE = 1.078580e-07
# Epoch 265: Combined = 1.076242e-07 	 MSE = 1.076242e-07
# Epoch 266: Combined = 1.073903e-07 	 MSE = 1.073903e-07
# Epoch 267: Combined = 1.071565e-07 	 MSE = 1.071565e-07
# Epoch 268: Combined = 1.069227e-07 	 MSE = 1.069227e-07
# Epoch 269: Combined = 1.066889e-07 	 MSE = 1.066889e-07
# Epoch 270: Combined = 1.064551e-07 	 MSE = 1.064551e-07
# Epoch 271: Combined = 1.062214e-07 	 MSE = 1.062214e-07
# Epoch 272: Combined = 1.059877e-07 	 MSE = 1.059877e-07
# Epoch 273: Combined = 1.057540e-07 	 MSE = 1.057540e-07
# Epoch 274: Combined = 1.055203e-07 	 MSE = 1.055203e-07
# Epoch 275: Combined = 1.052867e-07 	 MSE = 1.052867e-07
# Epoch 276: Combined = 1.050531e-07 	 MSE = 1.050531e-07
# Epoch 277: Combined = 1.048196e-07 	 MSE = 1.048196e-07
# Epoch 278: Combined = 1.045861e-07 	 MSE = 1.045861e-07
# Epoch 279: Combined = 1.043526e-07 	 MSE = 1.043526e-07
# Epoch 280: Combined = 1.041192e-07 	 MSE = 1.041192e-07
# Epoch 281: Combined = 1.038859e-07 	 MSE = 1.038859e-07
# Epoch 282: Combined = 1.036526e-07 	 MSE = 1.036526e-07
# Epoch 283: Combined = 1.034193e-07 	 MSE = 1.034193e-07
# Epoch 284: Combined = 1.031861e-07 	 MSE = 1.031861e-07
# Epoch 285: Combined = 1.029530e-07 	 MSE = 1.029530e-07
# Epoch 286: Combined = 1.027199e-07 	 MSE = 1.027199e-07
# Epoch 287: Combined = 1.024869e-07 	 MSE = 1.024869e-07
# Epoch 288: Combined = 1.022540e-07 	 MSE = 1.022540e-07
# Epoch 289: Combined = 1.020211e-07 	 MSE = 1.020211e-07
# Epoch 290: Combined = 1.017883e-07 	 MSE = 1.017883e-07
# Epoch 291: Combined = 1.015556e-07 	 MSE = 1.015556e-07
# Epoch 292: Combined = 1.013230e-07 	 MSE = 1.013230e-07
# Epoch 293: Combined = 1.010904e-07 	 MSE = 1.010904e-07
# Epoch 294: Combined = 1.008580e-07 	 MSE = 1.008580e-07
# Epoch 295: Combined = 1.006256e-07 	 MSE = 1.006256e-07
# Epoch 296: Combined = 1.003933e-07 	 MSE = 1.003933e-07
# Epoch 297: Combined = 1.001611e-07 	 MSE = 1.001611e-07
# Epoch 298: Combined = 9.992895e-08 	 MSE = 9.992895e-08
# Epoch 299: Combined = 9.969693e-08 	 MSE = 9.969693e-08
# Epoch 300: Combined = 9.946498e-08 	 MSE = 9.946498e-08
# Epoch 301: Combined = 9.923317e-08 	 MSE = 9.923317e-08
# Epoch 302: Combined = 9.900144e-08 	 MSE = 9.900144e-08
# Epoch 303: Combined = 9.876985e-08 	 MSE = 9.876985e-08
# Epoch 304: Combined = 9.853832e-08 	 MSE = 9.853832e-08
# Epoch 305: Combined = 9.830689e-08 	 MSE = 9.830689e-08
# Epoch 306: Combined = 9.807559e-08 	 MSE = 9.807559e-08
# Epoch 307: Combined = 9.784444e-08 	 MSE = 9.784444e-08
# Epoch 308: Combined = 9.761336e-08 	 MSE = 9.761336e-08
# Epoch 309: Combined = 9.738243e-08 	 MSE = 9.738243e-08
# Epoch 310: Combined = 9.715158e-08 	 MSE = 9.715158e-08
# Epoch 311: Combined = 9.692089e-08 	 MSE = 9.692089e-08
# Epoch 312: Combined = 9.669030e-08 	 MSE = 9.669030e-08
# Epoch 313: Combined = 9.645986e-08 	 MSE = 9.645986e-08
# Epoch 314: Combined = 9.622953e-08 	 MSE = 9.622953e-08
# Epoch 315: Combined = 9.599933e-08 	 MSE = 9.599933e-08
# Epoch 316: Combined = 9.576927e-08 	 MSE = 9.576927e-08
# Epoch 317: Combined = 9.553932e-08 	 MSE = 9.553932e-08
# Epoch 318: Combined = 9.530956e-08 	 MSE = 9.530956e-08
# Epoch 319: Combined = 9.507989e-08 	 MSE = 9.507989e-08
# Epoch 320: Combined = 9.485038e-08 	 MSE = 9.485038e-08
# Epoch 321: Combined = 9.462102e-08 	 MSE = 9.462102e-08
# Epoch 322: Combined = 9.439182e-08 	 MSE = 9.439182e-08
# Epoch 323: Combined = 9.416271e-08 	 MSE = 9.416271e-08
# Epoch 324: Combined = 9.393380e-08 	 MSE = 9.393380e-08
# Epoch 325: Combined = 9.370502e-08 	 MSE = 9.370502e-08
# Epoch 326: Combined = 9.347640e-08 	 MSE = 9.347640e-08
# Epoch 327: Combined = 9.324794e-08 	 MSE = 9.324794e-08
# Epoch 328: Combined = 9.301964e-08 	 MSE = 9.301964e-08
# Epoch 329: Combined = 9.279149e-08 	 MSE = 9.279149e-08
# Epoch 330: Combined = 9.256349e-08 	 MSE = 9.256349e-08
# Epoch 331: Combined = 9.233570e-08 	 MSE = 9.233570e-08
# Epoch 332: Combined = 9.210804e-08 	 MSE = 9.210804e-08
# Epoch 333: Combined = 9.188054e-08 	 MSE = 9.188054e-08
# Epoch 334: Combined = 9.165321e-08 	 MSE = 9.165321e-08
# Epoch 335: Combined = 9.142608e-08 	 MSE = 9.142608e-08
# Epoch 336: Combined = 9.119910e-08 	 MSE = 9.119910e-08
# Epoch 337: Combined = 9.097231e-08 	 MSE = 9.097231e-08
# Epoch 338: Combined = 9.074568e-08 	 MSE = 9.074568e-08
# Epoch 339: Combined = 9.051923e-08 	 MSE = 9.051923e-08
# Epoch 340: Combined = 9.029296e-08 	 MSE = 9.029296e-08
# Epoch 341: Combined = 9.006688e-08 	 MSE = 9.006688e-08
# Epoch 342: Combined = 8.984099e-08 	 MSE = 8.984099e-08
# Epoch 343: Combined = 8.961529e-08 	 MSE = 8.961529e-08
# Epoch 344: Combined = 8.938975e-08 	 MSE = 8.938975e-08
# Epoch 345: Combined = 8.916443e-08 	 MSE = 8.916443e-08
# Epoch 346: Combined = 8.893929e-08 	 MSE = 8.893929e-08
# Epoch 347: Combined = 8.871434e-08 	 MSE = 8.871434e-08
# Epoch 348: Combined = 8.848959e-08 	 MSE = 8.848959e-08
# Epoch 349: Combined = 8.826502e-08 	 MSE = 8.826502e-08
# Epoch 350: Combined = 8.804066e-08 	 MSE = 8.804066e-08
# Epoch 351: Combined = 8.781652e-08 	 MSE = 8.781652e-08
# Epoch 352: Combined = 8.759257e-08 	 MSE = 8.759257e-08
# Epoch 353: Combined = 8.736882e-08 	 MSE = 8.736882e-08
# Epoch 354: Combined = 8.714527e-08 	 MSE = 8.714527e-08
# Epoch 355: Combined = 8.692193e-08 	 MSE = 8.692193e-08
# Epoch 356: Combined = 8.669883e-08 	 MSE = 8.669883e-08
# Epoch 357: Combined = 8.647590e-08 	 MSE = 8.647590e-08
# Epoch 358: Combined = 8.625318e-08 	 MSE = 8.625318e-08
# Epoch 359: Combined = 8.603070e-08 	 MSE = 8.603070e-08
# Epoch 360: Combined = 8.580840e-08 	 MSE = 8.580840e-08
# Epoch 361: Combined = 8.558636e-08 	 MSE = 8.558636e-08
# Epoch 362: Combined = 8.536453e-08 	 MSE = 8.536453e-08
# Epoch 363: Combined = 8.514289e-08 	 MSE = 8.514289e-08
# Epoch 364: Combined = 8.492151e-08 	 MSE = 8.492151e-08
# Epoch 365: Combined = 8.470033e-08 	 MSE = 8.470033e-08
# Epoch 366: Combined = 8.447938e-08 	 MSE = 8.447938e-08
# Epoch 367: Combined = 8.425866e-08 	 MSE = 8.425866e-08
# Epoch 368: Combined = 8.403817e-08 	 MSE = 8.403817e-08
# Epoch 369: Combined = 8.381789e-08 	 MSE = 8.381789e-08
# Epoch 370: Combined = 8.359789e-08 	 MSE = 8.359789e-08
# Epoch 371: Combined = 8.337807e-08 	 MSE = 8.337807e-08
# Epoch 372: Combined = 8.315853e-08 	 MSE = 8.315853e-08
# Epoch 373: Combined = 8.293918e-08 	 MSE = 8.293918e-08
# Epoch 374: Combined = 8.272010e-08 	 MSE = 8.272010e-08
# Epoch 375: Combined = 8.250124e-08 	 MSE = 8.250124e-08
# Epoch 376: Combined = 8.228263e-08 	 MSE = 8.228263e-08
# Epoch 377: Combined = 8.206426e-08 	 MSE = 8.206426e-08
# Epoch 378: Combined = 8.184613e-08 	 MSE = 8.184613e-08
# Epoch 379: Combined = 8.162827e-08 	 MSE = 8.162827e-08
# Epoch 380: Combined = 8.141061e-08 	 MSE = 8.141061e-08
# Epoch 381: Combined = 8.119323e-08 	 MSE = 8.119323e-08
# Epoch 382: Combined = 8.097608e-08 	 MSE = 8.097608e-08
# Epoch 383: Combined = 8.075919e-08 	 MSE = 8.075919e-08
# Epoch 384: Combined = 8.054255e-08 	 MSE = 8.054255e-08
# Epoch 385: Combined = 8.032618e-08 	 MSE = 8.032618e-08
# Epoch 386: Combined = 8.011003e-08 	 MSE = 8.011003e-08
# Epoch 387: Combined = 7.989417e-08 	 MSE = 7.989417e-08
# Epoch 388: Combined = 7.967857e-08 	 MSE = 7.967857e-08
# Epoch 389: Combined = 7.946320e-08 	 MSE = 7.946320e-08
# Epoch 390: Combined = 7.924811e-08 	 MSE = 7.924811e-08
# Epoch 391: Combined = 7.903328e-08 	 MSE = 7.903328e-08
# Epoch 392: Combined = 7.881869e-08 	 MSE = 7.881869e-08
# Epoch 393: Combined = 7.860440e-08 	 MSE = 7.860440e-08
# Epoch 394: Combined = 7.839035e-08 	 MSE = 7.839035e-08
# Epoch 395: Combined = 7.817656e-08 	 MSE = 7.817656e-08
# Epoch 396: Combined = 7.796307e-08 	 MSE = 7.796307e-08
# Epoch 397: Combined = 7.774982e-08 	 MSE = 7.774982e-08
# Epoch 398: Combined = 7.753685e-08 	 MSE = 7.753685e-08
# Epoch 399: Combined = 7.732415e-08 	 MSE = 7.732415e-08
# Epoch 400: Combined = 7.711172e-08 	 MSE = 7.711172e-08

# %%
torch.set_printoptions(precision=5)
model.Sr.weight
# Out:
# Parameter containing:
# tensor([[ 0.78378,  0.45416],
#         [-0.10201, -0.28438]], dtype=torch.float64, requires_grad=True)

# %%
import matplotlib.pyplot as plt
import numpy as np

figsize = (10, 6)
xlim = (0, 0.2)

vin, fs = librosa.load("./ltspice/input_fuzz_static.wav", sr=None)
vin = torch.tensor(vin, dtype=torch.float32).unsqueeze(1)
v_spice = librosa.load("./ltspice/output_fuzz_static.wav", sr=None)[0]
v_spice = torch.tensor(v_spice, dtype=torch.float32).unsqueeze(1)

model = FuzzStatic()
model.reset_waves()
model.solve_dc(vin[0, 0])
v_wdf = model(vin)

v_wdf_np = v_wdf.detach().numpy().squeeze()
v_spice_np = v_spice.numpy().squeeze()
y_axis = np.linspace(0, v_wdf_np.shape[0] / fs, v_wdf_np.shape[0])

# 创建一个图形和两个子图（ax1 和 ax2）
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=figsize)

# 在第一个子图上绘制原始信号对比
ax1.plot(y_axis, v_spice_np, color="grey", linewidth=3)
ax1.plot(y_axis, v_wdf_np, color="red", linewidth=1)
ax1.set_xlabel("Time (s)")
ax1.set_ylabel("Amplitude")
ax1.set_title("WDF vs LTSpice")
ax1.legend(["LTSpice", "WDF"])
ax1.set_xlim(xlim)
# ax1.set_xticks(np.arange(0, 5.5, 0.5))

# 计算差值信号square error
square_error = (v_spice_np - v_wdf_np) ** 2

# 在第二个子图上绘制差值信号图
ax2.plot(y_axis, square_error, color="blue", linewidth=1)
ax2.set_xlabel("Time (s)")
ax2.set_ylabel("Square Error")
ax2.set_title("Square Error Between WDF and Spice")
ax2.set_xlim(xlim)
# ax2.set_xticks(np.arange(0, 5.5, 0.5))

plt.tight_layout()  # 调整子图的间距
plt.show()
# Out:
# Iterations: 352258
# Stable states:
#   C71: tensor(-0.4168, dtype=torch.float64, grad_fn=<AddBackward0>)
#   C81: tensor(3.2742, dtype=torch.float64, grad_fn=<AddBackward0>)
#   C91: tensor(-3.0281e-06, dtype=torch.float64, grad_fn=<AddBackward0>)
#   C94: tensor(-6.4850, dtype=torch.float64, grad_fn=<UnbindBackward0>)
